# %%
#Set1
questions_data = [
    {
        "id": 1,
        "narrator": "What does the woman imply?",
        "script_eng": "(Man): I can’t believe the library is closed already. It’s only 5 PM.\n(Woman): I know. They switched to the summer schedule starting today.",
        "choices_eng": [
            "(A) The library is open late today.",
            "(B) She thinks the man is wrong.",
            "(C) The library hours have changed.",
            "(D) They should come back in the summer."
        ]
    },
    {
        "id": 2,
        "narrator": "What does the man mean?",
        "script_eng": "(Woman): This chemistry assignment is impossible. I've been staring at it for hours.\n(Man): Tell me about it. I'm still on the first problem myself.",
        "choices_eng": [
            "(A) He wants the woman to explain the assignment.",
            "(B) He has finished the first problem.",
            "(C) He agrees that the assignment is difficult.",
            "(D) He thinks the woman should study more."
        ]
    },
    {
        "id": 3,
        "narrator": "What does the woman mean?",
        "script_eng": "(Man): Are you going to the concert in the park this afternoon?\n(Woman): Depends on the weather. The forecast said it might rain.",
        "choices_eng": [
            "(A) She definitely won't go to the concert.",
            "(B) She prefers indoor concerts.",
            "(C) She will go if the weather is good.",
            "(D) She hasn't checked the forecast yet."
        ]
    },
    {
        "id": 4,
        "narrator": "What will the man probably do next?",
        "script_eng": "(Woman): Excuse me, I think there is a mistake in my bill. I was charged for two desserts.\n(Man): Oh, I'm terribly sorry. Let me check that and print a new one for you.",
        "choices_eng": [
            "(A) Bring the woman a dessert.",
            "(B) Correct the error on the bill.",
            "(C) Ask the woman to pay the bill immediately.",
            "(D) Call the manager."
        ]
    },
    {
        "id": 5,
        "narrator": "What does the woman suggest?",
        "script_eng": "(Man): I really need to get in touch with Professor Miller, but he's not in his office.\n(Woman): Why don't you try dropping him an email? He usually replies pretty fast.",
        "choices_eng": [
            "(A) Waiting at the office.",
            "(B) Calling the professor.",
            "(C) Sending an email.",
            "(D) Dropping the class."
        ]
    },
    {
        "id": 6,
        "narrator": "What does the man imply?",
        "script_eng": "(Woman): Do you know if there are any seats left for the 7 o'clock movie?\n(Man): I doubt it. It’s the opening night and the line is around the block.",
        "choices_eng": [
            "(A) The movie starts at 7 o'clock.",
            "(B) There are likely no tickets available.",
            "(C) The block is closed for the movie.",
            "(D) He will stand in line for her."
        ]
    },
    {
        "id": 7,
        "narrator": "What does the woman imply about the course?",
        "script_eng": "(Man): I’m thinking about taking the advanced physics course next semester.\n(Woman): You might want to think twice. I heard it’s extremely demanding.",
        "choices_eng": [
            "(A) It is a very popular course.",
            "(B) The man should take it twice.",
            "(C) It is very difficult.",
            "(D) It requires two textbooks."
        ]
    },
    {
        "id": 8,
        "narrator": "What does the man suggest?",
        "script_eng": "(Woman): Should we take a taxi to the airport? We have a lot of luggage.\n(Man): Actually, the subway station is right downstairs and it goes directly to the terminal.",
        "choices_eng": [
            "(A) Taking the subway.",
            "(B) Hiring a taxi.",
            "(C) Carrying the luggage downstairs.",
            "(D) Asking for directions."
        ]
    },
    {
        "id": 9,
        "narrator": "What does the woman mean?",
        "script_eng": "(Man): Have you finished reading the novel for English class?\n(Woman): Finished it? I haven’t even bought the book yet!",
        "choices_eng": [
            "(A) She finished the book long ago.",
            "(B) She lost the book.",
            "(C) She has not started reading it.",
            "(D) She cannot afford the book."
        ]
    },
    {
        "id": 10,
        "narrator": "What does the man imply the woman should do?",
        "script_eng": "(Woman): I’m looking for a gift for my sister. She loves painting.\n(Man): Well, the art supply store across the street is having a big sale on brushes and canvases.",
        "choices_eng": [
            "(A) Buy a painting from him.",
            "(B) Go to the art supply store.",
            "(C) Paint a picture for her sister.",
            "(D) Wait for a sale next week."
        ]
    }
]

# %%
#set2
questions_data = [
    {
        "id": 1,
        "narrator": "What does the woman suggest the man do?",
        "script_eng": "(Man): I’ve been looking for an apartment for two weeks, but everything is too expensive.\n(Woman): Have you checked the bulletin board in the student center? Sometimes there are good deals there.",
        "narrator_thai": "ผู้หญิงแนะนำให้ผู้ชายทำอะไร?",
        "script_thai": "(Man): ผมหาอพาร์ตเมนต์มาสองอาทิตย์แล้ว แต่ทุกที่แพงไปหมดเลย\n(Woman): คุณลองเช็คบอร์ดประกาศที่ศูนย์นักเรียนหรือยัง? บางทีก็มีที่พักราคาดีๆ แปะอยู่นะ",
        "choices_eng": [
            "(A) Post an ad on the bulletin board.",
            "(B) Look for an apartment in the student center.",
            "(C) Check the board for apartment listings.",
            "(D) Buy a cheaper apartment."
        ],
        "choices_thai": [
            "(ไปแปะประกาศโฆษณาบนบอร์ด)",
            "(ไปหาอพาร์ตเมนต์ในศูนย์นักเรียน)",
            "(ไปดูรายการที่พักบนบอร์ดประกาศ)",
            "(ซื้ออพาร์ตเมนต์ที่ถูกกว่านี้)"
        ],
        "answer_text": "เฉลย: (C)\nอธิบาย: ผู้หญิงแนะนำให้ 'checked the bulletin board' (เช็คบอร์ดประกาศ) เพื่อหา 'good deals' (ข้อเสนอดีๆ/ที่พักราคาถูก)"
    },
    {
        "id": 2,
        "narrator": "What does the man imply?",
        "script_eng": "(Woman): You look terrible. Are you feeling okay?\n(Man): I think I came down with a flu. I might skip the history lecture today.",
        "narrator_thai": "ผู้ชายบอกเป็นนัยว่าอะไร?",
        "script_thai": "(Woman): คุณดูอาการแย่จัง รู้สึกโอเคไหม?\n(Man): ผมคิดว่าผมเป็นหวัดซะแล้ว วันนี้คงต้องโดดคลาสบรรยายวิชาประวัติศาสตร์",
        "choices_eng": [
            "(A) He doesn't like history.",
            "(B) He is feeling sick.",
            "(C) He fell down on his way to class.",
            "(D) He will go to the lecture anyway."
        ],
        "choices_thai": [
            "(เขาไม่ชอบวิชาประวัติศาสตร์)",
            "(เขารู้สึกป่วย/ไม่สบาย)",
            "(เขาล้มลงระหว่างทางไปเรียน)",
            "(เขาจะไปเข้าเรียนอยู่ดี)"
        ],
        "answer_text": "เฉลย: (B)\nอธิบาย: สำนวน 'came down with a flu' แปลว่า ป่วยเป็นไข้หวัด และเขาบอกว่าจะ 'skip' (โดด/ไม่เข้า) คลาสเรียน"
    },
    {
        "id": 3,
        "narrator": "What does the woman mean?",
        "script_eng": "(Man): Look at the traffic! We are never going to make the 5 o'clock train.\n(Woman): We’d better run if we want to catch it.",
        "narrator_thai": "ผู้หญิงหมายความว่าอย่างไร?",
        "script_thai": "(Man): ดูรถติดสิ! เราไม่มีทางไปทันรถไฟรอบ 5 โมงเย็นแน่ๆ\n(Woman): เราคงต้องวิ่งแล้วล่ะถ้าอยากจะขึ้นรถไฟให้ทัน",
        "choices_eng": [
            "(A) They should drive faster.",
            "(B) They have plenty of time.",
            "(C) They should take a taxi.",
            "(D) They need to hurry."
        ],
        "choices_thai": [
            "(พวกเขาควรขับรถให้เร็วขึ้น)",
            "(พวกเขามีเวลาเหลือเฟือ)",
            "(พวกเขาควรนั่งแท็กซี่)",
            "(พวกเขาจำเป็นต้องรีบ)"
        ],
        "answer_text": "เฉลย: (D)\nอธิบาย: ผู้หญิงบอกว่า 'better run' (ควรวิ่ง) เพื่อจะ 'catch it' (ขึ้นรถให้ทัน) แสดงว่าต้องรีบมากๆ (hurry)"
    },
    {
        "id": 4,
        "narrator": "What implies about the man?",
        "script_eng": "(Woman): How did you do on the final exam?\n(Man): I studied for three nights in a row, but I barely passed.",
        "narrator_thai": "บทสนทนาบอกอะไรเกี่ยวกับผู้ชาย?",
        "script_thai": "(Woman): คุณทำข้อสอบปลายภาคเป็นยังไงบ้าง?\n(Man): ผมอ่านหนังสือติดต่อกัน 3 คืนเลยนะ แต่ก็สอบผ่านแบบเฉียดฉิว",
        "choices_eng": [
            "(A) He failed the exam.",
            "(B) The exam was easy.",
            "(C) He didn't study enough.",
            "(D) The exam was difficult for him."
        ],
        "choices_thai": [
            "(เขาสอบตก)",
            "(ข้อสอบนั้นง่าย)",
            "(เขาอ่านหนังสือไม่พอ)",
            "(ข้อสอบนั้นยากสำหรับเขา)"
        ],
        "answer_text": "เฉลย: (D)\nอธิบาย: แม้เขาจะอ่านหนังสือหนัก (studied 3 nights) แต่ก็แค่ผ่านแบบเฉียดฉิว (barely passed) แสดงว่าข้อสอบมันยากสำหรับเขา"
    },
    {
        "id": 5,
        "narrator": "What will the man probably do?",
        "script_eng": "(Man): This shirt is a bit too tight. I don't think I can wear it.\n(Woman): Do you have the receipt? You can usually exchange it within 30 days.",
        "narrator_thai": "ผู้ชายจะทำอะไร?",
        "script_thai": "(Man): เสื้อตัวนี้มันคับไปหน่อย ผมคิดว่าใส่ไม่ได้แน่\n(Woman): คุณมีใบเสร็จไหม? ปกติแล้วคุณสามารถเปลี่ยนคืนได้ภายใน 30 วันนะ",
        "choices_eng": [
            "(A) Lose weight to fit in the shirt.",
            "(B) Return or exchange the shirt.",
            "(C) Give the shirt to the woman.",
            "(D) Buy a receipt."
        ],
        "choices_thai": [
            "(ลดน้ำหนักเพื่อให้ใส่เสื้อได้)",
            "(คืนหรือเปลี่ยนเสื้อ)",
            "(ยกเสื้อให้ผู้หญิง)",
            "(ซื้อใบเสร็จ)"
        ],
        "answer_text": "เฉลย: (B)\nอธิบาย: ปัญหาคือเสื้อคับ (too tight) ผู้หญิงแนะนำให้ใช้ใบเสร็จเพื่อ 'exchange' (เปลี่ยนสินค้า) ดังนั้นเขาน่าจะเอาไปเปลี่ยน"
    },
    {
        "id": 6,
        "narrator": "What is the man's opinion of the restaurant?",
        "script_eng": "(Woman): I heard the new Italian restaurant downtown is supposed to be great.\n(Man): I went there last night. The service was slow, and the food was cold.",
        "narrator_thai": "ผู้ชายมีความเห็นอย่างไรกับร้านอาหาร?",
        "script_thai": "(Woman): ฉันได้ยินมาว่าร้านอาหารอิตาเลียนเปิดใหม่ในเมืองยอดเยี่ยมมากเลยนะ\n(Man): ผมไปมาเมื่อคืน บริการช้ามาก แถมอาหารก็เย็นชืด",
        "choices_eng": [
            "(A) He recommends it.",
            "(B) It is better than he expected.",
            "(C) He was disappointed with it.",
            "(D) He wants to go there again."
        ],
        "choices_thai": [
            "(เขาแนะนำร้านนี้)",
            "(มันดีกว่าที่เขาคาดไว้)",
            "(เขารู้สึกผิดหวังกับร้านนี้)",
            "(เขาอยากไปที่นั่นอีก)"
        ],
        "answer_text": "เฉลย: (C)\nอธิบาย: เขาตำหนิว่า 'service was slow' และ 'food was cold' ซึ่งเป็นคำวิจารณ์เชิงลบ แสดงความผิดหวัง (Disappointed)"
    },
    {
        "id": 7,
        "narrator": "What does the woman imply?",
        "script_eng": "(Man): The printer is jammed again. I can't get my paper out.\n(Woman): Why don't you call the technician? I'm tired of trying to fix it myself.",
        "narrator_thai": "ผู้หญิงบอกเป็นนัยว่าอะไร?",
        "script_thai": "(Man): เครื่องปรินท์กระดาษติดอีกแล้ว ผมเอากระดาษออกมาไม่ได้เลย\n(Man): ทำไมคุณไม่เรียกช่างเทคนิคล่ะ? ฉันเหนื่อยที่จะพยายามซ่อมเองแล้วนะ",
        "choices_eng": [
            "(A) She will fix it for him.",
            "(B) He should buy a new printer.",
            "(C) She doesn't want to repair it.",
            "(D) The technician is already there."
        ],
        "choices_thai": [
            "(เธอจะซ่อมให้เขา)",
            "(เขาควรซื้อเครื่องปรินท์ใหม่)",
            "(เธอไม่อยากจะซ่อมมัน)",
            "(ช่างเทคนิคอยู่ที่นั่นแล้ว)"
        ],
        "answer_text": "เฉลย: (C)\nอธิบาย: ผู้หญิงพูดว่า 'I'm tired of trying to fix it myself' (ฉันเหนื่อยที่จะซ่อมเองแล้ว) แปลว่าเธอไม่อยากซ่อมมันอีกแล้ว"
    },
    {
        "id": 8,
        "narrator": "What does the man mean?",
        "script_eng": "(Woman): It's pouring rain outside. I don't have an umbrella.\n(Man): I guess the picnic is off then.",
        "narrator_thai": "ผู้ชายหมายความว่าอย่างไร?",
        "script_thai": "(Woman): ฝนตกหนักมากข้างนอกนั่น ฉันไม่ได้พกร่มมาด้วย\n(Man): ผมเดาว่าปิกนิกคงต้องยกเลิกแล้วล่ะ",
        "choices_eng": [
            "(A) They will have the picnic inside.",
            "(B) They are canceling the picnic.",
            "(C) He will go buy an umbrella.",
            "(D) The rain will stop soon."
        ],
        "choices_thai": [
            "(พวกเขาจะปิกนิกข้างในร่ม)",
            "(พวกเขากำลังจะยกเลิกปิกนิก)",
            "(เขาจะออกไปซื้อร่ม)",
            "(ฝนจะหยุดเร็วๆ นี้)"
        ],
        "answer_text": "เฉลย: (B)\nอธิบาย: สำนวน 'the picnic is off' หมายถึง งานปิกนิกถูกยกเลิก (Canceled) เนื่องจากฝนตก"
    },
    {
        "id": 9,
        "narrator": "What does the woman suggest?",
        "script_eng": "(Man): I can't find the biology textbook on the shelf. The computer says it's available.\n(Woman): Did you check the reserve desk? The professor might have put it there.",
        "narrator_thai": "ผู้หญิงแนะนำว่าอะไร?",
        "script_thai": "(Man): ผมหาหนังสือเรียนชีววิทยาบนชั้นวางไม่เจอเลย ในคอมบอกว่ามีของอยู่นะ\n(Woman): คุณลองเช็คที่โต๊ะหนังสือสำรองหรือยัง? อาจารย์อาจจะเอามันไปไว้ตรงนั้น",
        "choices_eng": [
            "(A) Ask the professor for a book.",
            "(B) Check the computer again.",
            "(C) Look in a different location.",
            "(D) Buy the book."
        ],
        "choices_thai": [
            "(ขอหนังสือจากอาจารย์)",
            "(เช็คในคอมพิวเตอร์อีกรอบ)",
            "(ลองดูในสถานที่อื่น)",
            "(ซื้อหนังสือ)"
        ],
        "answer_text": "เฉลย: (C)\nอธิบาย: ผู้หญิงแนะนำให้ไปดูที่ 'reserve desk' ซึ่งเป็นคนละที่กับชั้นวางปกติ (Shelf) ดังนั้นคือการแนะนำให้หาในที่อื่น (Different location)"
    },
    {
        "id": 10,
        "narrator": "What does the man imply?",
        "script_eng": "(Woman): Can you help me review this report? It's due tomorrow morning.\n(Man): I'm swamped right now, but maybe I can take a look after lunch.",
        "narrator_thai": "ผู้ชายบอกเป็นนัยว่าอะไร?",
        "script_thai": "(Woman): คุณช่วยฉันดูรายงานฉบับนี้หน่อยได้ไหม? ต้องส่งพรุ่งนี้เช้าแล้ว\n(Man): ตอนนี้ผมงานท่วมหัวเลย (ยุ่งมาก) แต่หลังมื้อเที่ยงอาจจะมาดูให้ได้นะ",
        "choices_eng": [
            "(A) He is swimming right now.",
            "(B) He doesn't want to help.",
            "(C) He is busy at the moment.",
            "(D) He will help her tomorrow."
        ],
        "choices_thai": [
            "(เขากำลังว่ายน้ำอยู่)",
            "(เขาไม่อยากช่วย)",
            "(ตอนนี้เขากำลังยุ่ง)",
            "(เขาจะช่วยเธอพรุ่งนี้)"
        ],
        "answer_text": "เฉลย: (C)\nอธิบาย: สำนวน 'I'm swamped' แปลว่า งานเยอะมากหรือยุ่งมาก (Busy) ในขณะนี้"
    }
]

# %%
#set3
questions_data = [
    {
        "id": 1,
        "narrator": "What does the woman imply?",
        "script_eng": "(Man): I have to pay a fine for this book. I thought it was due tomorrow.\n(Woman): You should have checked the date stamp on the back.",
        "narrator_thai": "ผู้หญิงต้องการจะสื่อว่าอะไร?",
        "script_thai": "(Man): ผมต้องจ่ายค่าปรับสำหรับหนังสือเล่มนี้ ผมนึกว่ามันกำหนดคืนพรุ่งนี้ซะอีก\n(Woman): คุณน่าจะเช็ควันที่ประทับตราด้านหลังนะ",
        "choices_eng": [
            "(A) The man is correct about the date.",
            "(B) The man should have been more careful.",
            "(C) The book is not due yet.",
            "(D) The library made a mistake."
        ],
        "choices_thai": [
            "(ผู้ชายเข้าใจวันที่ถูกต้องแล้ว)",
            "(ผู้ชายควรจะระมัดระวังมากกว่านี้)",
            "(หนังสือยังไม่ถึงกำหนดคืน)",
            "(ห้องสมุดทำผิดพลาด)"
        ],
        "answer_text": "เฉลย: (B)\nอธิบาย: ผู้หญิงตำหนิเบาๆ ว่า 'should have checked' (น่าจะเช็คดูหน่อย) แสดงว่าเธอคิดว่าเขาประมาท (Careless) ที่ไม่ดูวันที่ให้ดี"
    },
    {
        "id": 2,
        "narrator": "What will they probably do next?",
        "script_eng": "(Woman): The line at the cafeteria is out the door.\n(Man): Let's grab a sandwich at the snack bar instead. I have class in 20 minutes.",
        "narrator_thai": "พวกเขาจะทำอะไรต่อไป?",
        "script_thai": "(Woman): แถวที่โรงอาหารยาวออกไปนอกประตูเลย\n(Man): งั้นไปซื้อแซนวิชที่บาร์ขนมแทนเถอะ ผมมีเรียนในอีก 20 นาที",
        "choices_eng": [
            "(A) Wait in line at the cafeteria.",
            "(B) Skip lunch and go to class.",
            "(C) Eat at the snack bar.",
            "(D) Cook their own lunch."
        ],
        "choices_thai": [
            "(รอคิวที่โรงอาหาร)",
            "(งดมื้อเที่ยงแล้วไปเรียน)",
            "(ไปกินที่บาร์ขนม)",
            "(ทำอาหารกลางวันกินเอง)"
        ],
        "answer_text": "เฉลย: (C)\nอธิบาย: ผู้ชายเสนอทางเลือก (Suggestion) ว่า 'Let's grab a sandwich at the snack bar' เพื่อประหยัดเวลา"
    },
    {
        "id": 3,
        "narrator": "What does the woman suggest?",
        "script_eng": "(Man): I tried to sign up for the psychology class, but it's closed.\n(Woman): You can put your name on the waiting list. Someone might drop out.",
        "narrator_thai": "ผู้หญิงแนะนำว่าอะไร?",
        "script_thai": "(Man): ผมพยายามจะลงทะเบียนวิชาจิตวิทยา แต่มันปิดรับแล้ว (เต็มแล้ว)\n(Woman): คุณลงชื่อในบัญชีรายชื่อสำรองได้นะ เผื่อมีคนถอนรายวิชา",
        "choices_eng": [
            "(A) Take a different class.",
            "(B) Talk to the professor.",
            "(C) Put his name on the waiting list.",
            "(D) Drop out of school."
        ],
        "choices_thai": [
            "(ไปเรียนวิชาอื่น)",
            "(ไปคุยกับอาจารย์)",
            "(ลงชื่อในบัญชีสำรอง)",
            "(ลาออกจากโรงเรียน)"
        ],
        "answer_text": "เฉลย: (C)\nอธิบาย: คำแนะนำของผู้หญิงระบุชัดเจนว่า 'put your name on the waiting list' (ลงชื่อในบัญชีสำรอง)"
    },
    {
        "id": 4,
        "narrator": "What does the man mean?",
        "script_eng": "(Woman): Excuse me, I'm looking for the Science Building.\n(Man): It's right next to the library, just across the quad.",
        "narrator_thai": "ผู้ชายหมายความว่าอย่างไร?",
        "script_thai": "(Woman): ขอโทษนะคะ ฉันกำลังหาตึกวิทยาศาสตร์อยู่\n(Man): มันอยู่ติดกับห้องสมุดเลยครับ แค่ข้ามสนามหญ้ากลางตึกไป",
        "choices_eng": [
            "(A) He doesn't know where it is.",
            "(B) The building is far away.",
            "(C) The building is closed.",
            "(D) The building is nearby."
        ],
        "choices_thai": [
            "(เขาไม่รู้ว่ามันอยู่ที่ไหน)",
            "(ตึกอยู่ไกลมาก)",
            "(ตึกปิดอยู่)",
            "(ตึกอยู่ใกล้ๆ แถวนี้)"
        ],
        "answer_text": "เฉลย: (D)\nอธิบาย: ผู้ชายบอกตำแหน่งว่า 'right next to the library' (ติดกับห้องสมุด) แสดงว่ามันอยู่ใกล้ๆ (Nearby)"
    },
    {
        "id": 5,
        "narrator": "What will the woman probably do?",
        "script_eng": "(Man): Can you turn the music down? I'm trying to study for the midterm.\n(Woman): Oh, sorry. I didn't realize it was bothering you. I'll use my headphones.",
        "narrator_thai": "ผู้หญิงน่าจะทำอะไรต่อไป?",
        "script_thai": "(Man): คุณช่วยหรี่เพลงลงหน่อยได้ไหม? ผมพยายามจะอ่านหนังสือสอบมิดเทอมอยู่\n(Woman): โอ้ ขอโทษที ฉันไม่รู้ว่ามันรบกวนคุณ เดี๋ยวฉันจะใช้หูฟังแทน",
        "choices_eng": [
            "(A) Turn the music up.",
            "(B) Stop studying.",
            "(C) Use headphones.",
            "(D) Leave the room."
        ],
        "choices_thai": [
            "(เร่งเสียงเพลงขึ้น)",
            "(เลิกอ่านหนังสือ)",
            "(ใช้หูฟัง)",
            "(ออกจากห้อง)"
        ],
        "answer_text": "เฉลย: (C)\nอธิบาย: ผู้หญิงตอบรับคำขอและเสนอทางแก้ปัญหาเองว่า 'I'll use my headphones' (ฉันจะใช้หูฟัง)"
    },
    {
        "id": 6,
        "narrator": "What does the man mean?",
        "script_eng": "(Woman): Are you coming to the photography club meeting tonight?\n(Man): I wish I could, but I have to work a double shift at the bookstore.",
        "narrator_thai": "ผู้ชายหมายความว่าอย่างไร?",
        "script_thai": "(Woman): คุณจะมาประชุมชมรมถ่ายภาพคืนนี้ไหม?\n(Man): ผมอยากไปนะ แต่ผมต้องทำงานกะสองรอบที่ร้านหนังสือหน่ะ",
        "choices_eng": [
            "(A) He will go to the meeting.",
            "(B) He is quitting his job.",
            "(C) He has to work tonight.",
            "(D) He wants to buy a book."
        ],
        "choices_thai": [
            "(เขาจะไปร่วมประชุม)",
            "(เขากำลังจะลาออกจากงาน)",
            "(เขาต้องทำงานคืนนี้)",
            "(เขาอยากซื้อหนังสือ)"
        ],
        "answer_text": "เฉลย: (C)\nอธิบาย: วลี 'I wish I could, but...' เป็นการปฏิเสธ และเหตุผลคือ 'have to work' (ต้องทำงาน)"
    },
    {
        "id": 7,
        "narrator": "What does the woman imply?",
        "script_eng": "(Man): All the computers in the lab are taken.\n(Woman): There's another lab in the basement of the engineering building. It's usually empty.",
        "narrator_thai": "ผู้หญิงบอกเป็นนัยว่าอะไร?",
        "script_thai": "(Man): คอมพิวเตอร์ในแล็บถูกใช้เต็มทุกเครื่องเลย\n(Woman): มีอีกแล็บนึงอยู่ที่ชั้นใต้ดินตึกวิศวะนะ ปกติมันจะว่าง",
        "choices_eng": [
            "(A) The man should buy a computer.",
            "(B) The engineering building is closed.",
            "(C) The man should try the other lab.",
            "(D) The computers are broken."
        ],
        "choices_thai": [
            "(ผู้ชายควรซื้อคอมพิวเตอร์)",
            "(ตึกวิศวะปิดอยู่)",
            "(ผู้ชายควรลองไปดูที่แล็บอื่น)",
            "(คอมพิวเตอร์เสีย)"
        ],
        "answer_text": "เฉลย: (C)\nอธิบาย: ผู้หญิงให้ข้อมูลเกี่ยวกับ 'another lab' (แล็บอื่น) ที่ว่างอยู่ เพื่อแนะนำทางเลือกให้ผู้ชายไปใช้ที่นั่นแทน"
    },
    {
        "id": 8,
        "narrator": "What does the man mean?",
        "script_eng": "(Woman): I missed the lecture yesterday. Could I borrow your notes?\n(Man): I wasn't there either. I was at the dentist.",
        "narrator_thai": "ผู้ชายหมายความว่าอย่างไร?",
        "script_thai": "(Woman): เมื่อวานฉันขาดเรียน ขอยืมสมุดจดของคุณหน่อยได้ไหม?\n(Man): ผมก็ไม่ได้เข้าเรียนเหมือนกัน ผมไปหาหมอฟันมา",
        "choices_eng": [
            "(A) He doesn't want to lend his notes.",
            "(B) He didn't take any notes.",
            "(C) He went to the lecture.",
            "(D) His notes are at the dentist."
        ],
        "choices_thai": [
            "(เขาไม่อยากให้ยืมสมุดจด)",
            "(เขาไม่ได้จดเลกเชอร์ไว้เลย)",
            "(เขาเข้าเรียน)",
            "(สมุดจดเขาอยู่ที่หมอฟัน)"
        ],
        "answer_text": "เฉลย: (B)\nอธิบาย: การที่เขาบอกว่า 'I wasn't there either' (ผมก็ไม่ได้อยู่ที่นั่น/ไม่ได้เข้าเรียน) แปลว่าเขาก็ย่อมไม่มีสมุดจด (Notes) ให้ยืม"
    },
    {
        "id": 9,
        "narrator": "What will the woman probably do?",
        "script_eng": "(Man): Do you want to go hiking this weekend? The weather is supposed to be perfect.\n(Woman): I'd love to, but I have a paper due on Monday morning.",
        "narrator_thai": "ผู้หญิงน่าจะทำอะไร?",
        "script_thai": "(Man): สุดสัปดาห์นี้ไปเดินป่ากันไหม? เขาว่าอากาศจะดีมากๆ เลยนะ\n(Woman): ฉันอยากไปนะ แต่ฉันมีรายงานต้องส่งเช้าวันจันทร์",
        "choices_eng": [
            "(A) Go hiking with the man.",
            "(B) Check the weather forecast.",
            "(C) Stay home and work on her paper.",
            "(D) Submit her paper on Tuesday."
        ],
        "choices_thai": [
            "(ไปเดินป่ากับผู้ชาย)",
            "(เช็คพยากรณ์อากาศ)",
            "(อยู่บ้านและทำรายงาน)",
            "(ส่งรายงานวันอังคาร)"
        ],
        "answer_text": "เฉลย: (C)\nอธิบาย: เธอปฏิเสธ (but...) เพราะมีงานต้องส่ง (paper due) ดังนั้นเธอจึงต้องทำงานนั้นให้เสร็จ"
    },
    {
        "id": 10,
        "narrator": "What does the man imply the woman should do?",
        "script_eng": "(Woman): I need to ask Dr. Smith about my research paper.\n(Man): His office hours are Tuesday and Thursday from 2 to 4.",
        "narrator_thai": "ผู้ชายแนะนำเป็นนัยว่าผู้หญิงควรทำอะไร?",
        "script_thai": "(Woman): ฉันต้องถามดร.สมิธเกี่ยวกับงานวิจัยของฉัน\n(Man): เวลาเข้าพบ (Office hours) ของเขาคือวันอังคารและพฤหัสบดี ตอนบ่าย 2 ถึง 4 โมง",
        "choices_eng": [
            "(A) Call Dr. Smith at home.",
            "(B) Visit Dr. Smith during office hours.",
            "(C) Send an email to Dr. Smith.",
            "(D) Wait for Dr. Smith in class."
        ],
        "choices_thai": [
            "(โทรหาดร.สมิธที่บ้าน)",
            "(ไปหาดร.สมิธช่วงเวลาเข้าพบ)",
            "(ส่งอีเมลหาดร.สมิธ)",
            "(รอดร.สมิธในห้องเรียน)"
        ],
        "answer_text": "เฉลย: (B)\nอธิบาย: ผู้ชายให้ข้อมูลเฉพาะเจาะจงเกี่ยวกับ 'office hours' เพื่อบอกว่าควรไปหาเขาในช่วงเวลานั้น"
    }
]

# %%
#set 4
questions_data = [
    {
        "id": 1,
        "narrator": "What does the woman suggest?",
        "script_eng": "(Man): It's so noisy in here. I can't concentrate on my reading.\n(Woman): Why don't we go up to the third floor? It's designated for quiet study.",
        "narrator_thai": "ผู้หญิงแนะนำว่าอะไร?",
        "script_thai": "(Man): ที่นี่เสียงดังมากเลย ผมไม่มีสมาธิอ่านหนังสือเลย\n(Woman): ทำไมเราไม่ขึ้นไปที่ชั้น 3 ล่ะ? ที่นั่นถูกกำหนดให้เป็นโซนเงียบสำหรับอ่านหนังสือนะ",
        "choices_eng": [
            "(A) Tell people to be quiet.",
            "(B) Go to the third floor.",
            "(C) Stop reading and go home.",
            "(D) Buy some earplugs."
        ],
        "choices_thai": [
            "(บอกให้คนอื่นเงียบ)",
            "(ขึ้นไปที่ชั้น 3)",
            "(เลิกอ่านหนังสือแล้วกลับบ้าน)",
            "(ซื้อที่อุดหู)"
        ],
        "answer_text": "เฉลย: (B)\nอธิบาย: ผู้หญิงเสนอทางเลือกโดยใช้ประโยค 'Why don't we...' เพื่อแนะนำให้ไปสถานที่ที่เงียบกว่า คือชั้น 3"
    },
    {
        "id": 2,
        "narrator": "What does the man imply?",
        "script_eng": "(Woman): The campus bus is taking forever. We're going to be late.\n(Man): We might as well walk. It only takes ten minutes to cross the campus.",
        "narrator_thai": "ผู้ชายบอกเป็นนัยว่าอะไร?",
        "script_thai": "(Woman): รถบัสของมหาลัยมาช้ามาก เราจะสายกันแล้วนะ\n(Man): เราเดินไปก็ได้นะ มันใช้เวลาแค่ 10 นาทีเองในการเดินข้ามวิทยาเขต",
        "choices_eng": [
            "(A) The bus is faster than walking.",
            "(B) They should wait for the bus.",
            "(C) Walking is a better option.",
            "(D) They will definitely be late."
        ],
        "choices_thai": [
            "(รถบัสเร็วกว่าเดิน)",
            "(พวกเขาควรรอรถบัส)",
            "(การเดินเป็นทางเลือกที่ดีกว่า)",
            "(พวกเขาจะสายแน่นอน)"
        ],
        "answer_text": "เฉลย: (C)\nอธิบาย: ผู้ชายเสนอว่า 'might as well walk' (เดินไปก็ได้/เดินไปดีกว่า) เพราะรถมาช้าและการเดินใช้เวลาไม่นาน"
    },
    {
        "id": 3,
        "narrator": "What does the woman imply the man should do?",
        "script_eng": "(Man): Do you remember when the history paper is due?\n(Woman): I'm not sure, but it should be listed on the syllabus.",
        "narrator_thai": "ผู้หญิงแนะนำเป็นนัยให้ผู้ชายทำอะไร?",
        "script_thai": "(Man): คุณจำได้ไหมว่ารายงานวิชาประวัติศาสตร์กำหนดส่งเมื่อไหร่?\n(Woman): ฉันไม่แน่ใจ แต่มันน่าจะระบุอยู่ในประมวลรายวิชา (Syllabus) นะ",
        "choices_eng": [
            "(A) Ask the professor.",
            "(B) Check the syllabus.",
            "(C) Submit the paper today.",
            "(D) Forget about the paper."
        ],
        "choices_thai": [
            "(ไปถามอาจารย์)",
            "(ตรวจสอบในประมวลรายวิชา)",
            "(ส่งรายงานวันนี้)",
            "(ลืมเรื่องรายงานไปซะ)"
        ],
        "answer_text": "เฉลย: (B)\nอธิบาย: ผู้หญิงบอกว่าข้อมูล 'should be listed on the syllabus' เป็นการแนะให้ผู้ชายไปดูข้อมูลจากตรงนั้น"
    },
    {
        "id": 4,
        "narrator": "What will the man probably do?",
        "script_eng": "(Woman): I’m starving. Let’s go check out that new burger place across the street.\n(Man): I’m trying to save money this month. I brought a sandwich from home.",
        "narrator_thai": "ผู้ชายน่าจะทำอะไร?",
        "script_thai": "(Woman): ฉันหิวจะตายอยู่แล้ว ไปดูร้านเบอร์เกอร์ใหม่ฝั่งตรงข้ามกันเถอะ\n(Man): เดือนนี้ผมพยายามประหยัดเงินอยู่ ผมพกแซนวิชมาจากบ้านหน่ะ",
        "choices_eng": [
            "(A) Go to the burger place.",
            "(B) Lend money to the woman.",
            "(C) Eat his own lunch.",
            "(D) Buy a sandwich."
        ],
        "choices_thai": [
            "(ไปที่ร้านเบอร์เกอร์)",
            "(ให้ผู้หญิงยืมเงิน)",
            "(กินอาหารกลางวันของตัวเอง)",
            "(ซื้อแซนวิช)"
        ],
        "answer_text": "เฉลย: (C)\nอธิบาย: เขาบอกว่า 'trying to save money' และ 'brought a sandwich' (เตรียมมาแล้ว) แสดงว่าเขาจะกินของที่เตรียมมา"
    },
    {
        "id": 5,
        "narrator": "What does the woman suggest?",
        "script_eng": "(Man): My roommate plays video games until 3 AM every night. I can't sleep.\n(Woman): Have you tried talking to the Resident Advisor about it?",
        "narrator_thai": "ผู้หญิงแนะนำว่าอะไร?",
        "script_thai": "(Man): รูมเมทผมเล่นเกมถึงตี 3 ทุกคืนเลย ผมนอนไม่หลับ\n(Woman): คุณลองไปคุยกับผู้ดูแลหอพัก (RA) เกี่ยวกับเรื่องนี้หรือยัง?",
        "choices_eng": [
            "(A) Play games with his roommate.",
            "(B) Move to a different room.",
            "(C) Speak to the Resident Advisor.",
            "(D) Sleep during the day."
        ],
        "choices_thai": [
            "(เล่นเกมกับรูมเมท)",
            "(ย้ายไปห้องอื่น)",
            "(ไปคุยกับผู้ดูแลหอพัก)",
            "(นอนตอนกลางวัน)"
        ],
        "answer_text": "เฉลย: (C)\nอธิบาย: ผู้หญิงแนะนำตรงๆ ว่าให้ 'talking to the Resident Advisor' เพื่อแก้ปัญหาความขัดแย้ง"
    },
    {
        "id": 6,
        "narrator": "What does the man imply?",
        "script_eng": "(Woman): I'm thinking of dropping Dr. Evans' class. The reading list is huge.\n(Man): It is a lot of work, but he's the best professor in the department.",
        "narrator_thai": "ผู้ชายบอกเป็นนัยว่าอะไร?",
        "script_thai": "(Woman): ฉันกำลังคิดว่าจะถอนวิชาของ ดร.อีแวนส์ รายการหนังสือที่ต้องอ่านมันเยอะมาก\n(Man): งานมันเยอะก็จริง แต่เขาเป็นอาจารย์ที่เก่งที่สุดในภาควิชาเลยนะ",
        "choices_eng": [
            "(A) The woman should drop the class.",
            "(B) The class is not worth the effort.",
            "(C) Dr. Evans is a terrible teacher.",
            "(D) The woman should stay in the class."
        ],
        "choices_thai": [
            "(ผู้หญิงควรถอนรายวิชา)",
            "(วิชานี้ไม่คุ้มค่าที่จะเรียน)",
            "(ดร.อีแวนส์ เป็นครูที่แย่)",
            "(ผู้หญิงควรเรียนวิชานี้ต่อไป)"
        ],
        "answer_text": "เฉลย: (D)\nอธิบาย: ผู้ชายใช้คำว่า 'but' เพื่อแย้งข้อเสีย และชมว่าอาจารย์เก่งที่สุด (best professor) เป็นการโน้มน้าวให้เรียนต่อ"
    },
    {
        "id": 7,
        "narrator": "What does the woman imply the man should do?",
        "script_eng": "(Man): My laptop screen just went black. I have a presentation tomorrow!\n(Woman): Don't panic. The computer center help desk is open until midnight.",
        "narrator_thai": "ผู้หญิงแนะนำเป็นนัยให้ผู้ชายทำอะไร?",
        "script_thai": "(Man): หน้าจอแล็ปท็อปผมดับไปเฉยเลย ผมมีพรีเซนต์งานพรุ่งนี้ด้วย!\n(Woman): อย่าเพิ่งตื่นตูมไป ศูนย์คอมพิวเตอร์เปิดถึงเที่ยงคืนนะ",
        "choices_eng": [
            "(A) Buy a new laptop.",
            "(B) Go to the computer center.",
            "(C) Cancel the presentation.",
            "(D) Fix the laptop himself."
        ],
        "choices_thai": [
            "(ซื้อแล็ปท็อปใหม่)",
            "(ไปที่ศูนย์คอมพิวเตอร์)",
            "(ยกเลิกการพรีเซนต์)",
            "(ซ่อมแล็ปท็อปด้วยตัวเอง)"
        ],
        "answer_text": "เฉลย: (B)\nอธิบาย: ผู้หญิงให้ข้อมูลว่า 'computer center... open until midnight' เพื่อแนะนำให้เขาเอาเครื่องไปซ่อมที่นั่น"
    },
    {
        "id": 8,
        "narrator": "What does the man mean?",
        "script_eng": "(Woman): I can't believe how cold it is today. I should have worn a heavier coat.\n(Man): The weather report said the temperature is going to drop even more tonight.",
        "narrator_thai": "ผู้ชายหมายความว่าอย่างไร?",
        "script_thai": "(Woman): ไม่อยากเชื่อเลยว่าวันนี้หนาวขนาดนี้ ฉันน่าจะใส่เสื้อโค้ทหนาๆ มา\n(Man): พยากรณ์อากาศบอกว่าอุณหภูมิจะลดลงอีกคืนนี้นะ",
        "choices_eng": [
            "(A) It will get warmer tonight.",
            "(B) The woman is dressed appropriately.",
            "(C) It will get colder later.",
            "(D) The weather report is wrong."
        ],
        "choices_thai": [
            "(คืนนี้จะอุ่นขึ้น)",
            "(ผู้หญิงแต่งตัวเหมาะสมแล้ว)",
            "(เดี๋ยวจะหนาวกว่านี้อีก)",
            "(พยากรณ์อากาศผิด)"
        ],
        "answer_text": "เฉลย: (C)\nอธิบาย: ผู้ชายบอกว่า 'temperature is going to drop' (อุณหภูมิจะลดลง) ซึ่งหมายความว่าอากาศจะเย็นลงกว่าเดิม (get colder)"
    },
    {
        "id": 9,
        "narrator": "What does the woman suggest?",
        "script_eng": "(Man): I need to get the dean's signature on this form immediately.\n(Woman): He's in a meeting right now, but his secretary can probably help you.",
        "narrator_thai": "ผู้หญิงแนะนำว่าอะไร?",
        "script_thai": "(Man): ผมต้องขอลายเซ็นคณบดีในใบนี้เดี๋ยวนี้เลย\n(Woman): ตอนนี้เขากำลังประชุมอยู่ แต่เลขาของเขาน่าจะช่วยคุณได้นะ",
        "choices_eng": [
            "(A) Interrupt the meeting.",
            "(B) Wait for the dean.",
            "(C) Talk to the secretary.",
            "(D) Come back tomorrow."
        ],
        "choices_thai": [
            "(เข้าไปขัดจังหวะการประชุม)",
            "(รอคณบดี)",
            "(ไปคุยกับเลขา)",
            "(กลับมาใหม่พรุ่งนี้)"
        ],
        "answer_text": "เฉลย: (C)\nอธิบาย: ผู้หญิงเสนอทางเลือกอื่นว่า 'secretary can probably help you' (เลขาช่วยได้) แทนการรอคณบดี"
    },
    {
        "id": 10,
        "narrator": "What does the man mean?",
        "script_eng": "(Woman): Are you ready for the presentation? It starts in ten minutes.\n(Man): Ten minutes? I thought we had an hour!",
        "narrator_thai": "ผู้ชายหมายความว่าอย่างไร?",
        "script_thai": "(Woman): คุณพร้อมสำหรับพรีเซนต์หรือยัง? จะเริ่มในอีก 10 นาทีแล้วนะ\n(Man): 10 นาทีเหรอ? ผมนึกว่าเราเหลือเวลาอีกตั้งชั่วโมงนึง!",
        "choices_eng": [
            "(A) He is ready for the presentation.",
            "(B) He thought the presentation was canceled.",
            "(C) He miscalculated the time.",
            "(D) He wants to start early."
        ],
        "choices_thai": [
            "(เขาพร้อมสำหรับการพรีเซนต์)",
            "(เขาคิดว่าการพรีเซนต์ถูกยกเลิก)",
            "(เขาคำนวณเวลาผิด)",
            "(เขาอยากเริ่มให้เร็วขึ้น)"
        ],
        "answer_text": "เฉลย: (C)\nอธิบาย: ผู้ชายตกใจและบอกว่า 'thought we had an hour' (นึกว่ามีเวลาอีกชั่วโมง) แสดงว่าเขาจำเวลาผิดหรือกะเวลาผิด (Miscalculated)"
    }
]

# %%
#Set5
questions_data = [
    {
        "id": 1,
        "narrator": "What does the woman imply?",
        "script_eng": "(Man): I'm thinking of buying that used car we saw yesterday.\n(Woman): Are you sure? It seemed to have a lot of mileage on it.",
        "narrator_thai": "ผู้หญิงบอกเป็นนัยว่าอะไร?",
        "script_thai": "(Man): ผมกำลังคิดว่าจะซื้อรถมือสองคันที่เราไปดูเมื่อวาน\n(Woman): คุณแน่ใจเหรอ? ดูเหมือนรถคันนั้นจะเลขไมล์เยอะมากเลยนะ (วิ่งมาเยอะ)",
        "choices_eng": [
            "(A) The man should buy the car.",
            "(B) The car is in good condition.",
            "(C) The car might not be a good purchase.",
            "(D) She wants to buy the car herself."
        ],
        "choices_thai": [
            "(ผู้ชายควรซื้อรถคันนั้น)",
            "(รถอยู่ในสภาพดี)",
            "(รถคันนั้นอาจจะไม่ใช่การซื้อที่คุ้มค่านัก)",
            "(เธออยากซื้อรถคันนั้นเอง)"
        ],
        "answer_text": "เฉลย: (C)\nอธิบาย: ผู้หญิงทักท้วงว่า 'Are you sure?' และชี้ข้อเสียเรื่อง 'lot of mileage' (เลขไมล์เยอะ) เป็นนัยว่ารถสภาพไม่ดีและไม่น่าซื้อ"
    },
    {
        "id": 2,
        "narrator": "What does the man mean?",
        "script_eng": "(Woman): I'm having trouble with this calculus problem. It's so confusing.\n(Man): Don't look at me. Math was never my strong suit.",
        "narrator_thai": "ผู้ชายหมายความว่าอย่างไร?",
        "script_thai": "(Woman): ฉันกำลังงงกับโจทย์แคลคูลัสข้อนี้ มันสับสนจัง\n(Man): อย่ามองผมสิ (อย่าหวังพึ่งผม) วิชาเลขไม่เคยเป็นจุดแข็งของผมเลย",
        "choices_eng": [
            "(A) He is very good at math.",
            "(B) He can help her with the problem.",
            "(C) He doesn't like the woman.",
            "(D) He is not good at math."
        ],
        "choices_thai": [
            "(เขาเก่งเลขมาก)",
            "(เขาสามารถช่วยเธอทำโจทย์ได้)",
            "(เขาไม่ชอบผู้หญิงคนนี้)",
            "(เขาไม่เก่งเลข)"
        ],
        "answer_text": "เฉลย: (D)\nอธิบาย: สำนวน 'never my strong suit' หมายความว่า ไม่เก่งหรือไม่ถนัดเรื่องนั้นๆ"
    },
    {
        "id": 3,
        "narrator": "What will the woman probably do?",
        "script_eng": "(Man): The elevator is broken again. We'll have to take the stairs to the 10th floor.\n(Woman): You go ahead. I'll wait for the next elevator in the lobby.",
        "narrator_thai": "ผู้หญิงน่าจะทำอะไร?",
        "script_thai": "(Man): ลิฟต์เสียอีกแล้ว เราต้องเดินขึ้นบันไดไปชั้น 10 กันแล้วล่ะ\n(Woman): คุณไปก่อนเลย ฉันจะรอลิฟต์ตัวถัดไปที่ล็อบบี้",
        "choices_eng": [
            "(A) Walk up the stairs.",
            "(B) Fix the elevator.",
            "(C) Wait for another elevator.",
            "(D) Leave the building."
        ],
        "choices_thai": [
            "(เดินขึ้นบันได)",
            "(ซ่อมลิฟต์)",
            "(รอลิฟต์ตัวอื่น)",
            "(ออกจากตึก)"
        ],
        "answer_text": "เฉลย: (C)\nอธิบาย: ผู้หญิงพูดชัดเจนว่า 'I'll wait for the next elevator' (ฉันจะรอลิฟต์ตัวถัดไป)"
    },
    {
        "id": 4,
        "narrator": "What does the man suggest?",
        "script_eng": "(Woman): I left my wallet in the classroom, but the door is locked now.\n(Man): Security should have a key. Let's go find an officer.",
        "narrator_thai": "ผู้ชายแนะนำว่าอะไร?",
        "script_thai": "(Woman): ฉันลืมกระเป๋าตังค์ไว้ในห้องเรียน แต่ตอนนี้ประตูล็อคไปแล้ว\n(Man): ฝ่ายรักษาความปลอดภัยน่าจะมีกุญแจนะ เราไปหาเจ้าหน้าที่กันเถอะ",
        "choices_eng": [
            "(A) Break the door open.",
            "(B) Ask a security officer for help.",
            "(C) Leave the wallet there.",
            "(D) Call the professor."
        ],
        "choices_thai": [
            "(พังประตูเข้าไป)",
            "(ขอความช่วยเหลือจากเจ้าหน้าที่ รปภ.)",
            "(ทิ้งกระเป๋าตังค์ไว้ที่นั่น)",
            "(โทรหาอาจารย์)"
        ],
        "answer_text": "เฉลย: (B)\nอธิบาย: ผู้ชายแนะนำว่า 'Let's go find an officer' (ไปหาเจ้าหน้าที่กันเถอะ) เพื่อให้มาช่วยเปิดประตู"
    },
    {
        "id": 5,
        "narrator": "What does the woman imply about the presentation?",
        "script_eng": "(Man): How did your presentation go this morning?\n(Woman): Well, let's just say I'm glad it's over.",
        "narrator_thai": "ผู้หญิงบอกเป็นนัยเกี่ยวกับการนำเสนองานว่าอย่างไร?",
        "script_thai": "(Man): การนำเสนองานเมื่อเช้าเป็นยังไงบ้าง?\n(Woman): เอาเป็นว่า ฉันดีใจที่มันจบลงสักที",
        "choices_eng": [
            "(A) It went extremely well.",
            "(B) She wants to do it again.",
            "(C) It didn't go very well.",
            "(D) It was too short."
        ],
        "choices_thai": [
            "(มันผ่านไปได้ด้วยดีมากๆ)",
            "(เธออยากทำมันอีกครั้ง)",
            "(มันไม่ค่อยดีเท่าไหร่)",
            "(มันสั้นเกินไป)"
        ],
        "answer_text": "เฉลย: (C)\nอธิบาย: วลี 'I'm glad it's over' (ดีใจที่มันจบไปซะที) มักใช้เมื่อเหตุการณ์นั้นยากลำบากหรือไม่น่าอภิรมย์ สื่อเป็นนัยว่าผลลัพธ์ไม่ค่อยดีนัก"
    },
    {
        "id": 6,
        "narrator": "What does the man mean?",
        "script_eng": "(Woman): Do you want to try the new seafood place tonight?\n(Man): I'm not really a big fan of fish.",
        "narrator_thai": "ผู้ชายหมายความว่าอย่างไร?",
        "script_thai": "(Woman): คืนนี้คุณอยากไปลองร้านอาหารทะเลเปิดใหม่ไหม?\n(Man): ผมไม่ค่อยชอบกินปลาเท่าไหร่นะ",
        "choices_eng": [
            "(A) He loves seafood.",
            "(B) He wants to go to the restaurant.",
            "(C) He is a fan of the restaurant.",
            "(D) He prefers not to eat seafood."
        ],
        "choices_thai": [
            "(เขาชอบอาหารทะเลมาก)",
            "(เขาอยากไปที่ร้านอาหารนั้น)",
            "(เขาเป็นแฟนคลับของร้านนั้น)",
            "(เขาเลือกที่จะไม่กินอาหารทะเล)"
        ],
        "answer_text": "เฉลย: (D)\nอธิบาย: สำนวน 'not a big fan of...' แปลว่า ไม่ค่อยชอบ ดังนั้นเขาจึงไม่อยากไปกิน (Prefers not to eat)"
    },
    {
        "id": 7,
        "narrator": "What does the woman suggest the man do?",
        "script_eng": "(Man): I've got a terrible headache, and I have a chemistry lab in an hour.\n(Woman): If I were you, I’d take some aspirin and lie down for a bit.",
        "narrator_thai": "ผู้หญิงแนะนำให้ผู้ชายทำอะไร?",
        "script_thai": "(Man): ผมปวดหัวจี๊ดเลย แล้วมีเรียนแล็บเคมีในอีกชั่วโมงนึงด้วย\n(Woman): ถ้าฉันเป็นคุณ ฉันจะกินยาแอสไพรินแล้วนอนพักสักหน่อย",
        "choices_eng": [
            "(A) Go to the chemistry lab immediately.",
            "(B) Take medicine and rest.",
            "(C) Study for the lab.",
            "(D) See a doctor."
        ],
        "choices_thai": [
            "(ไปเข้าแล็บเคมีทันที)",
            "(กินยาและพักผ่อน)",
            "(อ่านหนังสือเตรียมเข้าแล็บ)",
            "(ไปหาหมอ)"
        ],
        "answer_text": "เฉลย: (B)\nอธิบาย: คำแนะนำคือ 'take some aspirin' (กินยา) และ 'lie down' (นอนพัก/rest)"
    },
    {
        "id": 8,
        "narrator": "What implies about the assignment?",
        "script_eng": "(Woman): Have you started writing your essay yet?\n(Man): Started it? I handed it in two days ago!",
        "narrator_thai": "บทสนทนาบอกอะไรเกี่ยวกับงานเขียน?",
        "script_thai": "(Woman): คุณเริ่มเขียนเรียงความหรือยัง?\n(Man): เริ่มเหรอ? ผมส่งงานไปตั้งแต่ 2 วันที่แล้วแล้ว!",
        "choices_eng": [
            "(A) The man hasn't started it yet.",
            "(B) The man is writing it now.",
            "(C) The man finished it early.",
            "(D) The man lost the essay."
        ],
        "choices_thai": [
            "(ผู้ชายยังไม่ได้เริ่มทำ)",
            "(ผู้ชายกำลังเขียนอยู่)",
            "(ผู้ชายทำเสร็จก่อนกำหนด)",
            "(ผู้ชายทำเรียงความหาย)"
        ],
        "answer_text": "เฉลย: (C)\nอธิบาย: ผู้ชายบอกว่า 'handed it in two days ago' (ส่งไป 2 วันแล้ว) แสดงว่าเขาทำเสร็จเร็ว (Finished early) ก่อนที่ผู้หญิงจะถามเสียอีก"
    },
    {
        "id": 9,
        "narrator": "What does the woman mean?",
        "script_eng": "(Man): I can't believe we have to buy three textbooks for this course. They are so expensive.\n(Woman): Tell me about it. My wallet is empty.",
        "narrator_thai": "ผู้หญิงหมายความว่าอย่างไร?",
        "script_thai": "(Man): ไม่อยากเชื่อเลยว่าเราต้องซื้อหนังสือเรียนตั้ง 3 เล่มสำหรับวิชานี้ แพงชะมัด\n(Woman): เห็นด้วยสุดๆ กระเป๋าตังค์ฉันเกลี้ยงแล้วเนี่ย",
        "choices_eng": [
            "(A) She has lost her wallet.",
            "(B) She disagrees with the man.",
            "(C) She thinks the books are cheap.",
            "(D) She agrees that the books are expensive."
        ],
        "choices_thai": [
            "(เธอทำกระเป๋าตังค์หาย)",
            "(เธอไม่เห็นด้วยกับผู้ชาย)",
            "(เธอคิดว่าหนังสือราคาถูก)",
            "(เธอเห็นด้วยว่าหนังสือแพง)"
        ],
        "answer_text": "เฉลย: (D)\nอธิบาย: วลี 'Tell me about it' เป็นการแสดงความเห็นด้วยอย่างยิ่ง และการบอกว่า 'wallet is empty' ย้ำว่าหนังสือแพงจนเงินหมด"
    },
    {
        "id": 10,
        "narrator": "What will the man probably do?",
        "script_eng": "(Woman): The library is closing in five minutes. You'd better check those books out now.\n(Man): Oh, thanks for the warning. I'll head to the front desk right away.",
        "narrator_thai": "ผู้ชายน่าจะทำอะไร?",
        "script_thai": "(Woman): ห้องสมุดจะปิดในอีก 5 นาทีนะ คุณรีบไปยืมหนังสือพวกนั้นเดี๋ยวนี้เลยดีกว่า\n(Man): โอ้ ขอบคุณที่เตือน ผมจะรีบไปที่เคาน์เตอร์เดี๋ยวนี้เลย",
        "choices_eng": [
            "(A) Leave the books on the table.",
            "(B) Go to the front desk to borrow books.",
            "(C) Complain to the librarian.",
            "(D) Continue reading."
        ],
        "choices_thai": [
            "(ทิ้งหนังสือไว้บนโต๊ะ)",
            "(ไปที่เคาน์เตอร์เพื่อยืมหนังสือ)",
            "(ไปบ่นกับบรรณารักษ์)",
            "(อ่านหนังสือต่อ)"
        ],
        "answer_text": "เฉลย: (B)\nอธิบาย: ผู้ชายตอบรับว่าจะ 'head to the front desk' (มุ่งหน้าไปที่เคาน์เตอร์) เพื่อทำเรื่องยืมหนังสือ (check out)"
    }
]

# %%
#Set 6
questions_data = [
    {
        "id": 1,
        "narrator": "What does the man imply?",
        "script_eng": "(Woman): I’m really struggling to make ends meet this month. Rent has gone up again.\n(Man): Maybe you should look into getting a roommate to split the costs.",
        "narrator_thai": "ผู้ชายบอกเป็นนัยว่าอะไร?",
        "script_thai": "(Woman): เดือนนี้ฉันลำบากเรื่องเงินมากเลย ค่าเช่าขึ้นราคาอีกแล้ว\n(Man): บางทีคุณน่าจะลองหารูมเมทมาช่วยหารค่าใช้จ่ายดูนะ",
        "choices_eng": [
            "(A) She should move to a cheaper apartment.",
            "(B) She should find someone to share the rent.",
            "(C) He will lend her some money.",
            "(D) The rent is reasonable."
        ],
        "choices_thai": [
            "(เธอควรย้ายไปอพาร์ตเมนต์ที่ถูกกว่า)",
            "(เธอควรหาคนมาช่วยหารค่าเช่า)",
            "(เขาจะให้เธอยืมเงิน)",
            "(ค่าเช่าสมเหตุสมผลแล้ว)"
        ],
        "answer_text": "เฉลย: (B)\nอธิบาย: ผู้ชายแนะนำให้ 'look into getting a roommate' (หารูมเมท) เพื่อ 'split the costs' (หารค่าใช้จ่าย) ซึ่งตรงกับ choice B"
    },
    {
        "id": 2,
        "narrator": "What does the woman mean?",
        "script_eng": "(Man): The professor said the final exam will cover everything from the beginning of the semester.\n(Woman): You’re kidding! I thought it was just going to be on the last few chapters.",
        "narrator_thai": "ผู้หญิงหมายความว่าอย่างไร?",
        "script_thai": "(Man): อาจารย์บอกว่าข้อสอบปลายภาคจะออกเนื้อหาตั้งแต่ต้นเทอมเลย\n(Woman): ล้อเล่นน่า! ฉันนึกว่าจะออกแค่ไม่กี่บทหลังซะอีก",
        "choices_eng": [
            "(A) She is happy about the exam format.",
            "(B) She thinks the man is joking.",
            "(C) She is surprised by the news.",
            "(D) She has already studied everything."
        ],
        "choices_thai": [
            "(เธอพอใจกับรูปแบบข้อสอบ)",
            "(เธอคิดว่าผู้ชายกำลังล้อเล่น)",
            "(เธอรู้สึกประหลาดใจกับข่าวนี้)",
            "(เธออ่านหนังสือครบหมดแล้ว)"
        ],
        "answer_text": "เฉลย: (C)\nอธิบาย: คำอุทาน 'You’re kidding!' แสดงความตกใจหรือไม่เชื่อในสิ่งที่ได้ยิน (Surprised) เพราะเธอเข้าใจผิดมาตลอด"
    },
    {
        "id": 3,
        "narrator": "What will the man probably do?",
        "script_eng": "(Woman): The printer is out of ink, and I need to print this report by noon.\n(Man): I’m heading to the supply store anyway. I can pick up a cartridge for you.",
        "narrator_thai": "ผู้ชายน่าจะทำอะไร?",
        "script_thai": "(Woman): เครื่องปรินท์หมึกหมด แล้วฉันต้องพิมพ์รายงานนี้ก่อนเที่ยงด้วยสิ\n(Man): ผมกำลังจะไปร้านเครื่องเขียนพอดี เดี๋ยวผมซื้อตลับหมึกมาให้ก็ได้",
        "choices_eng": [
            "(A) Repair the printer.",
            "(B) Buy an ink cartridge.",
            "(C) Type the report for her.",
            "(D) Go to lunch."
        ],
        "choices_thai": [
            "(ซ่อมเครื่องปรินท์)",
            "(ซื้อตลับหมึก)",
            "(พิมพ์รายงานให้เธอ)",
            "(ไปกินมื้อเที่ยง)"
        ],
        "answer_text": "เฉลย: (B)\nอธิบาย: ผู้ชายอาสาว่าจะ 'pick up a cartridge' (ซื้อตลับหมึกกลับมาให้) ระหว่างที่ไปร้านเครื่องเขียน"
    },
    {
        "id": 4,
        "narrator": "What does the woman imply about the lecture?",
        "script_eng": "(Man): Did you understand what Dr. Clark was talking about today? It went right over my head.\n(Woman): I was lost after the first ten minutes.",
        "narrator_thai": "ผู้หญิงบอกเป็นนัยเกี่ยวกับเลกเชอร์ว่าอย่างไร?",
        "script_thai": "(Man): คุณเข้าใจที่ดร.คลาร์กพูดวันนี้ไหม? ผมไม่รู้เรื่องเลย\n(Woman): ฉันงงตั้งแต่ 10 นาทีแรกแล้ว",
        "choices_eng": [
            "(A) It was very interesting.",
            "(B) She understood it perfectly.",
            "(C) It was confusing for her too.",
            "(D) She arrived late."
        ],
        "choices_thai": [
            "(มันน่าสนใจมาก)",
            "(เธอเข้าใจมันอย่างถ่องแท้)",
            "(มันน่าสับสนสำหรับเธอเหมือนกัน)",
            "(เธอมาสาย)"
        ],
        "answer_text": "เฉลย: (C)\nอธิบาย: สำนวน 'I was lost' ในบริบทนี้หมายถึง 'ตามไม่ทัน' หรือ 'ไม่เข้าใจ' (Confusing) เช่นเดียวกับผู้ชาย"
    },
    {
        "id": 5,
        "narrator": "What does the man suggest?",
        "script_eng": "(Woman): I’ve been feeling so lethargic lately. I just don’t have any energy.\n(Man): Why not try cutting back on caffeine and getting more sleep?",
        "narrator_thai": "ผู้ชายแนะนำว่าอะไร?",
        "script_thai": "(Woman): ช่วงนี้ฉันรู้สึกเฉื่อยชาจัง ไม่มีแรงเลย\n(Man): ทำไมไม่ลองลดคาเฟอีนลงแล้วก็นอนให้มากขึ้นดูล่ะ?",
        "choices_eng": [
            "(A) Drink more coffee.",
            "(B) See a doctor immediately.",
            "(C) Reduce caffeine intake.",
            "(D) Exercise more often."
        ],
        "choices_thai": [
            "(ดื่มกาแฟให้มากขึ้น)",
            "(ไปหาหมอทันที)",
            "(ลดการบริโภคคาเฟอีน)",
            "(ออกกำลังกายให้บ่อยขึ้น)"
        ],
        "answer_text": "เฉลย: (C)\nอธิบาย: คำแนะนำ 'cutting back on caffeine' หมายถึง ลดปริมาณคาเฟอีนลง (Reduce caffeine intake)"
    },
    {
        "id": 6,
        "narrator": "What does the woman mean?",
        "script_eng": "(Man): Are you still planning to go to the beach this weekend?\n(Woman): Only if the weather clears up. The forecast looks pretty grim.",
        "narrator_thai": "ผู้หญิงหมายความว่าอย่างไร?",
        "script_thai": "(Man): คุณยังวางแผนจะไปทะเลสุดสัปดาห์นี้อยู่ไหม?\n(Woman): ก็ต่อเมื่ออากาศดีขึ้นนะ พยากรณ์อากาศดูแย่มากเลย",
        "choices_eng": [
            "(A) She will go regardless of the weather.",
            "(B) She doubts she will go.",
            "(C) She thinks the weather will be nice.",
            "(D) She prefers the mountains."
        ],
        "choices_thai": [
            "(เธอจะไปไม่ว่าอากาศจะเป็นยังไง)",
            "(เธอสงสัยว่าคงจะไม่ได้ไป)",
            "(เธอคิดว่าอากาศจะดี)",
            "(เธอชอบภูเขามากกว่า)"
        ],
        "answer_text": "เฉลย: (B)\nอธิบาย: เธอตั้งเงื่อนไขว่า 'Only if the weather clears up' แต่บอกต่อว่าพยากรณ์อากาศ 'looks grim' (ดูแย่) ดังนั้นโอกาสไปจึงน้อยมาก (Doubts she will go)"
    },
    {
        "id": 7,
        "narrator": "What does the man imply about the book?",
        "script_eng": "(Woman): Have you finished reading the novel for our literature class?\n(Man): I couldn't put it down! I stayed up all night reading it.",
        "narrator_thai": "ผู้ชายบอกเป็นนัยเกี่ยวกับหนังสือว่าอย่างไร?",
        "script_thai": "(Woman): คุณอ่านนิยายสำหรับวิชาวรรณกรรมจบหรือยัง?\n(Man): ผมวางไม่ลงเลย! ผมอ่านโต้รุ่งทั้งคืนเลยเนี่ย",
        "choices_eng": [
            "(A) It was boring.",
            "(B) It was too long.",
            "(C) He didn't finish it.",
            "(D) It was very captivating."
        ],
        "choices_thai": [
            "(มันน่าเบื่อ)",
            "(มันยาวเกินไป)",
            "(เขายังอ่านไม่จบ)",
            "(มันน่าติดตามมาก)"
        ],
        "answer_text": "เฉลย: (D)\nอธิบาย: สำนวน 'couldn't put it down' ใช้ชมหนังสือว่าสนุกมากจนวางไม่ลง (Captivating/Exciting)"
    },
    {
        "id": 8,
        "narrator": "What will the woman probably do?",
        "script_eng": "(Man): The deadline for the scholarship application is tomorrow at 5 PM.\n(Woman): Oh no! I haven't even started my personal statement yet.",
        "narrator_thai": "ผู้หญิงน่าจะทำอะไร?",
        "script_thai": "(Man): กำหนดส่งใบสมัครทุนคือพรุ่งนี้ 5 โมงเย็นนะ\n(Woman): แย่แล้ว! ฉันยังไม่ได้เริ่มเขียนเรียงความแนะนำตัวเลย",
        "choices_eng": [
            "(A) Submit the application immediately.",
            "(B) Start writing her essay right away.",
            "(C) Ask for an extension.",
            "(D) Give up on the scholarship."
        ],
        "choices_thai": [
            "(ส่งใบสมัครทันที)",
            "(เริ่มเขียนเรียงความเดี๋ยวนี้เลย)",
            "(ขอขยายเวลาส่ง)",
            "(สละสิทธิ์ทุนการศึกษา)"
        ],
        "answer_text": "เฉลย: (B)\nอธิบาย: เมื่อรู้ว่าเดดไลน์ใกล้เข้ามาและงานยังไม่เริ่ม ปฏิกิริยาที่สมเหตุสมผลที่สุดคือต้องรีบเริ่มทำ (Start writing right away)"
    },
    {
        "id": 9,
        "narrator": "What does the man mean?",
        "script_eng": "(Woman): Do you think we should invite the neighbors to the party?\n(Man): Better safe than sorry. We don't want them complaining about the noise.",
        "narrator_thai": "ผู้ชายหมายความว่าอย่างไร?",
        "script_thai": "(Woman): คุณคิดว่าเราควรชวนเพื่อนบ้านมางานปาร์ตี้ไหม?\n(Man): กันไว้ดีกว่าแก้ เราคงไม่อยากให้เขามาบ่นเรื่องเสียงดังหรอกนะ",
        "choices_eng": [
            "(A) They should not invite the neighbors.",
            "(B) The neighbors will definitely complain.",
            "(C) It is a good idea to invite them.",
            "(D) The party will be quiet."
        ],
        "choices_thai": [
            "(พวกเขาไม่ควรเชิญเพื่อนบ้าน)",
            "(เพื่อนบ้านจะมาบ่นแน่นอน)",
            "(เป็นความคิดที่ดีที่จะเชิญพวกเขา)",
            "(งานปาร์ตี้จะเงียบสงบ)"
        ],
        "answer_text": "เฉลย: (C)\nอธิบาย: สำนวน 'Better safe than sorry' (กันไว้ดีกว่าแก้) ในที่นี้หมายถึง ควรเชิญไว้ก่อนเพื่อป้องกันปัญหา (Good idea to invite them)"
    },
    {
        "id": 10,
        "narrator": "What does the woman imply about the man's request?",
        "script_eng": "(Man): Could you cover my shift on Friday? I have a family emergency.\n(Woman): I’m already working a double shift that day, but maybe Sarah can help.",
        "narrator_thai": "ผู้หญิงบอกเป็นนัยเกี่ยวกับคำขอของผู้ชายว่าอย่างไร?",
        "script_thai": "(Man): คุณช่วยทำงานแทนผมวันศุกร์ได้ไหม? ที่บ้านผมมีเรื่องด่วน\n(Woman): วันนั้นฉันเข้ากะสองรอบอยู่แล้ว แต่บางทีซาร่าน่าจะช่วยได้นะ",
        "choices_eng": [
            "(A) She will cover his shift.",
            "(B) She is unable to help him.",
            "(C) Sarah is busy on Friday.",
            "(D) He should not ask for help."
        ],
        "choices_thai": [
            "(เธอจะทำงานแทนเขา)",
            "(เธอไม่สามารถช่วยเขาได้)",
            "(ซาร่าไม่ว่างวันศุกร์)",
            "(เขาไม่ควรขอความช่วยเหลือ)"
        ],
        "answer_text": "เฉลย: (B)\nอธิบาย: เธอปฏิเสธทางอ้อมโดยบอกเหตุผลว่า 'already working a double shift' (ทำงานหนักอยู่แล้ว) แปลว่าเธอช่วยไม่ได้ (Unable to help)"
    }
]

# %%
#set7
questions_data = [
    {
        "id": 1,
        "narrator": "What does the woman imply about the man?",
        "script_eng": "(Man): I’ve been working on this project day and night, and I still have three exams next week.\n(Woman): You really need to stop burning the candle at both ends, or you’ll get sick.",
        "narrator_thai": "ผู้หญิงบอกเป็นนัยเกี่ยวกับผู้ชายว่าอย่างไร?",
        "script_thai": "(Man): ผมทำโปรเจกต์นี้ทั้งวันทั้งคืนเลย แล้วอาทิตย์หน้ายังมีสอบอีก 3 วิชา\n(Woman): คุณต้องเลิกโหมงานหนักเกินตัวได้แล้วนะ ไม่งั้นเดี๋ยวจะป่วยเอา",
        "choices_eng": [
            "(A) He should buy some candles.",
            "(B) He is working too hard.",
            "(C) He has finished his exams.",
            "(D) He needs to turn on the lights."
        ],
        "choices_thai": [
            "(เขาควรซื้อเทียน)",
            "(เขากำลังทำงานหนักเกินไป)",
            "(เขาสอบเสร็จแล้ว)",
            "(เขาต้องเปิดไฟ)"
        ],
        "answer_text": "เฉลย: (B)\nอธิบาย: สำนวน 'burn the candle at both ends' หมายถึง การทำงานหนักมากจนไม่ได้พักผ่อน (Working too hard)"
    },
    {
        "id": 2,
        "narrator": "What does the man mean?",
        "script_eng": "(Woman): I thought the movie was incredibly boring. I nearly fell asleep.\n(Man): I couldn't agree more. It was a complete waste of time.",
        "narrator_thai": "ผู้ชายหมายความว่าอย่างไร?",
        "script_thai": "(Woman): ฉันว่าหนังเรื่องนี้น่าเบื่อสุดๆ ฉันเกือบจะหลับเลย\n(Man): เห็นด้วยอย่างยิ่ง มันเสียเวลาจริงๆ",
        "choices_eng": [
            "(A) He liked the movie.",
            "(B) He disagrees with the woman.",
            "(C) He shares the woman's opinion.",
            "(D) He fell asleep during the movie."
        ],
        "choices_thai": [
            "(เขาชอบหนังเรื่องนี้)",
            "(เขาไม่เห็นด้วยกับผู้หญิง)",
            "(เขามีความเห็นเหมือนกับผู้หญิง)",
            "(เขาหลับระหว่างดูหนัง)"
        ],
        "answer_text": "เฉลย: (C)\nอธิบาย: วลี 'I couldn't agree more' แปลว่า เห็นด้วยที่สุด (ไม่สามารถเห็นด้วยไปมากกว่านี้แล้ว) แสดงว่าเขาคิดเหมือนเธอ"
    },
    {
        "id": 3,
        "narrator": "What will the woman probably do next?",
        "script_eng": "(Man): My car wouldn't start this morning. I think it’s the battery.\n(Woman): Well, I have some jumper cables in my trunk. Let's see if we can get it running.",
        "narrator_thai": "ผู้หญิงน่าจะทำอะไรต่อไป?",
        "script_thai": "(Man): เมื่อเช้ารถผมสตาร์ทไม่ติด ผมคิดว่าเป็นที่แบตเตอรี่\n(Woman): อืม ฉันมีสายพ่วงแบตอยู่ท้ายรถ เดี๋ยวลองดูซิว่าเราจะทำให้มันสตาร์ทติดได้ไหม",
        "choices_eng": [
            "(A) Call a mechanic.",
            "(B) Buy a new battery.",
            "(C) Help the man start his car.",
            "(D) Drive the man to work."
        ],
        "choices_thai": [
            "(โทรเรียกช่างยนต์)",
            "(ซื้อแบตเตอรี่ใหม่)",
            "(ช่วยผู้ชายสตาร์ทรถ)",
            "(ขับรถไปส่งผู้ชายที่ทำงาน)"
        ],
        "answer_text": "เฉลย: (C)\nอธิบาย: ผู้หญิงเสนอตัวช่วยโดยใช้ 'jumper cables' (สายพ่วงแบต) เพื่อลองสตาร์ทรถดู (get it running)"
    },
    {
        "id": 4,
        "narrator": "What does the man imply?",
        "script_eng": "(Woman): How did your interview go? Did you get the job?\n(Man): Don't ask. I was so nervous I could barely speak.",
        "narrator_thai": "ผู้ชายบอกเป็นนัยว่าอะไร?",
        "script_thai": "(Woman): สัมภาษณ์เป็นไงบ้าง? ได้งานไหม?\n(Man): อย่าถามเลย ผมตื่นเต้นมากจนแทบจะพูดไม่ออก",
        "choices_eng": [
            "(A) The interview went well.",
            "(B) He is confident he got the job.",
            "(C) The interview went poorly.",
            "(D) He refused to answer the questions."
        ],
        "choices_thai": [
            "(การสัมภาษณ์ผ่านไปได้ด้วยดี)",
            "(เขามั่นใจว่าจะได้งาน)",
            "(การสัมภาษณ์แย่มาก)",
            "(เขาปฏิเสธที่จะตอบคำถาม)"
        ],
        "answer_text": "เฉลย: (C)\nอธิบาย: วลี 'Don't ask' มักใช้เมื่อไม่อยากพูดถึงเรื่องที่ผิดพลาด และการที่เขาบอกว่า 'barely speak' แสดงว่าผลลัพธ์น่าจะไม่ดี (Poorly)"
    },
    {
        "id": 5,
        "narrator": "What does the woman suggest?",
        "script_eng": "(Man): I can't decide whether to accept the job offer in New York or stay here.\n(Woman): It's a big decision. Why don't you sleep on it and tell them tomorrow?",
        "narrator_thai": "ผู้หญิงแนะนำว่าอะไร?",
        "script_thai": "(Man): ผมตัดสินใจไม่ได้ว่าจะรับข้อเสนองานที่นิวยอร์กหรืออยู่ที่นี่ต่อดี\n(Woman): มันเป็นการตัดสินใจที่ใหญ่นะ ทำไมคุณไม่นอนคิดสักคืนแล้วค่อยบอกพวกเขาพรุ่งนี้ล่ะ?",
        "choices_eng": [
            "(A) Accept the offer immediately.",
            "(B) Go to sleep right now.",
            "(C) Delay the decision until later.",
            "(D) Move to New York."
        ],
        "choices_thai": [
            "(ตอบรับข้อเสนอทันที)",
            "(ไปนอนเดี๋ยวนี้)",
            "(ชะลอการตัดสินใจออกไปก่อน)",
            "(ย้ายไปนิวยอร์ก)"
        ],
        "answer_text": "เฉลย: (C)\nอธิบาย: สำนวน 'sleep on it' หมายถึง ให้เวลาไตร่ตรองอีกสักคืนก่อนตัดสินใจ (Delay the decision)"
    },
    {
        "id": 6,
        "narrator": "What does the man imply about the party?",
        "script_eng": "(Woman): Was there a big turnout at the alumni party last night?\n(Man): Honestly, you could count the number of people on one hand.",
        "narrator_thai": "ผู้ชายบอกเป็นนัยเกี่ยวกับงานปาร์ตี้ว่าอย่างไร?",
        "script_thai": "(Woman): เมื่อคืนมีคนไปงานเลี้ยงศิษย์เก่าเยอะไหม?\n(Man): เอาจริงๆ นะ คุณนับจำนวนคนด้วยนิ้วมือข้างเดียวก็ครบแล้ว",
        "choices_eng": [
            "(A) It was extremely crowded.",
            "(B) Very few people attended.",
            "(C) Everyone raised their hands.",
            "(D) He didn't go to the party."
        ],
        "choices_thai": [
            "(คนแน่นมาก)",
            "(มีคนไปร่วมน้อยมาก)",
            "(ทุกคนยกมือขึ้น)",
            "(เขาไม่ได้ไปงานปาร์ตี้)"
        ],
        "answer_text": "เฉลย: (B)\nอธิบาย: สำนวน 'count on one hand' (นับได้ด้วยมือข้างเดียว) เปรียบเปรยว่าจำนวนน้อยมาก (Very few people)"
    },
    {
        "id": 7,
        "narrator": "What does the woman mean?",
        "script_eng": "(Man): I tried to call the registrar's office, but I kept getting a busy signal.\n(Man): You'll have better luck if you call first thing in the morning.",
        "narrator_thai": "ผู้หญิงหมายความว่าอย่างไร?",
        "script_thai": "(Man): ผมพยายามโทรหาสำนักงานทะเบียน แต่สายไม่ว่างตลอดเลย\n(Woman): คุณน่าจะมีโอกาสมากกว่าถ้าโทรไปเป็นอย่างแรกตอนเช้าตรู่",
        "choices_eng": [
            "(A) The office is closed in the morning.",
            "(B) He should call back later today.",
            "(C) It is easier to get through early in the day.",
            "(D) He needs luck to win."
        ],
        "choices_thai": [
            "(สำนักงานปิดตอนเช้า)",
            "(เขาควรโทรกลับมาใหม่สายๆ วันนี้)",
            "(โทรติดง่ายกว่าในช่วงเช้าตรู่)",
            "(เขาต้องใช้ดวงเพื่อที่จะชนะ)"
        ],
        "answer_text": "เฉลย: (C)\nอธิบาย: วลี 'first thing in the morning' หมายถึง เช้าตรู่หรือตอนเปิดทำการ ซึ่งเธอบอกว่าจะมีโอกาสดีกว่า (easier to get through)"
    },
    {
        "id": 8,
        "narrator": "What implies about the man's paper?",
        "script_eng": "(Woman): Have you finished typing your research paper yet?\n(Man): Finished? I haven't even finalized my thesis statement!",
        "narrator_thai": "บทสนทนาบอกอะไรเกี่ยวกับรายงานของผู้ชาย?",
        "script_thai": "(Woman): คุณพิมพ์รายงานวิจัยเสร็จหรือยัง?\n(Man): เสร็จเหรอ? ผมยังสรุปหัวข้อวิทยานิพนธ์ไม่ได้เลยด้วยซ้ำ!",
        "choices_eng": [
            "(A) It is almost complete.",
            "(B) It is ready to be printed.",
            "(C) He has barely started it.",
            "(D) He lost his thesis statement."
        ],
        "choices_thai": [
            "(มันเกือบเสร็จสมบูรณ์แล้ว)",
            "(มันพร้อมที่จะปรินท์แล้ว)",
            "(เขาแทบจะยังไม่ได้เริ่มเลย)",
            "(เขาทำหัวข้อวิทยานิพนธ์หาย)"
        ],
        "answer_text": "เฉลย: (C)\nอธิบาย: การที่เขายังไม่เสร็จแม้กระทั่ง 'thesis statement' (ซึ่งเป็นส่วนแรกๆ ของการทำวิจัย) แสดงว่าเขายังแทบไม่ได้เริ่ม (Barely started)"
    },
    {
        "id": 9,
        "narrator": "What does the woman suggest?",
        "script_eng": "(Man): This coffee machine is so complicated. I can't figure out how to make a latte.\n(Woman): There should be an instruction manual in the drawer.",
        "narrator_thai": "ผู้หญิงแนะนำว่าอะไร?",
        "script_thai": "(Man): เครื่องชงกาแฟนี่ซับซ้อนชะมัด ผมทำไม่ถูกเลยว่าจะชงลาเต้ยังไง\n(Woman): มันน่าจะมีคู่มือการใช้งานอยู่ในลิ้นชักนะ",
        "choices_eng": [
            "(A) Ask someone for help.",
            "(B) Read the manual.",
            "(C) Buy a new machine.",
            "(D) Drink espresso instead."
        ],
        "choices_thai": [
            "(ขอให้คนช่วย)",
            "(อ่านคู่มือ)",
            "(ซื้อเครื่องใหม่)",
            "(ดื่มเอสเพรสโซ่แทน)"
        ],
        "answer_text": "เฉลย: (B)\nอธิบาย: ผู้หญิงชี้เป้าว่าคู่มือ (instruction manual) อยู่ในลิ้นชัก เป็นนัยแนะนำให้ไปหยิบมาอ่านดู"
    },
    {
        "id": 10,
        "narrator": "What does the man imply?",
        "script_eng": "(Woman): Are you going to join the gym this semester? It's expensive, but it has a pool.\n(Man): It costs an arm and a leg! I'll just stick to jogging in the park.",
        "narrator_thai": "ผู้ชายบอกเป็นนัยว่าอะไร?",
        "script_thai": "(Woman): เทอมนี้คุณจะสมัครยิมไหม? มันแพงหน่อยนะ แต่มีสระว่ายน้ำด้วย\n(Man): ราคาเลือดตาแทบกระเด็น! ผมขอวิ่งจ๊อกกิ้งในสวนเหมือนเดิมดีกว่า",
        "choices_eng": [
            "(A) He hurt his arm and leg.",
            "(B) He thinks the gym is affordable.",
            "(C) The gym is too expensive for him.",
            "(D) He prefers swimming to jogging."
        ],
        "choices_thai": [
            "(เขาเจ็บแขนและขา)",
            "(เขาคิดว่าราคายิมพอจ่ายไหว)",
            "(ยิมราคาแพงเกินไปสำหรับเขา)",
            "(เขาชอบว่ายน้ำมากกว่าวิ่ง)"
        ],
        "answer_text": "เฉลย: (C)\nอธิบาย: สำนวน 'costs an arm and a leg' แปลว่า แพงมากๆ ดังนั้นเขาจึงไม่สมัครและเลือกไปวิ่งที่สวนแทน"
    }
]

# %%
#set8
questions_data = [
    {
        "id": 1,
        "narrator": "What does the woman imply?",
        "script_eng": "(Man): I really need to get this package mailed today. It's urgent.\n(Woman): Well, the post office closes in ten minutes, and it's a twenty-minute drive from here.",
        "narrator_thai": "ผู้หญิงบอกเป็นนัยว่าอะไร?",
        "script_thai": "(Man): ผมจำเป็นต้องส่งพัสดุนี้ภายในวันนี้จริงๆ มันด่วนมาก\n(Woman): อืม ไปรษณีย์จะปิดในอีก 10 นาที และจากที่นี่ต้องขับรถไป 20 นาทีนะ",
        "choices_eng": [
            "(A) The man should drive faster.",
            "(B) The man will likely miss the deadline.",
            "(C) The post office is close by.",
            "(D) She will drive him to the post office."
        ],
        "choices_thai": [
            "(ผู้ชายควรขับรถให้เร็วขึ้น)",
            "(ผู้ชายไม่น่าจะไปทันกำหนด)",
            "(ที่ทำการไปรษณีย์อยู่ใกล้ๆ)",
            "(เธอจะขับรถไปส่งเขา)"
        ],
        "answer_text": "เฉลย: (B)\nอธิบาย: ผู้หญิงให้ข้อมูลเรื่องเวลา (ปิดใน 10 นาที) และระยะทาง (ขับรถ 20 นาที) ซึ่งขัดแย้งกัน สื่อเป็นนัยว่าเขาจะไปไม่ทัน (Likely miss the deadline)"
    },
    {
        "id": 2,
        "narrator": "What does the man mean?",
        "script_eng": "(Woman): How did you find the new art exhibit at the museum?\n(Man): To be honest, it wasn't exactly my cup of tea.",
        "narrator_thai": "ผู้ชายหมายความว่าอย่างไร?",
        "script_thai": "(Woman): คุณรู้สึกยังไงกับนิทรรศการศิลปะใหม่ที่พิพิธภัณฑ์บ้าง?\n(Man): พูดตรงๆ นะ มันไม่ใช่แนวของผมเท่าไหร่ (ไม่ใช่ถ้วยชาของผม)",
        "choices_eng": [
            "(A) He enjoyed the tea at the museum.",
            "(B) He didn't like the exhibit.",
            "(C) He thinks the art was beautiful.",
            "(D) He wants to go back again."
        ],
        "choices_thai": [
            "(เขาชอบชาที่พิพิธภัณฑ์)",
            "(เขาไม่ชอบนิทรรศการนั้น)",
            "(เขาคิดว่างานศิลปะสวยงาม)",
            "(เขาอยากกลับไปอีกครั้ง)"
        ],
        "answer_text": "เฉลย: (B)\nอธิบาย: สำนวน 'not my cup of tea' แปลว่า ไม่ใช่สิ่งที่ชอบ หรือไม่ใช่แนวที่ถนัด (Didn't like it)"
    },
    {
        "id": 3,
        "narrator": "What does the woman suggest?",
        "script_eng": "(Man): I’ve been staring at this math problem for an hour and I still can’t solve it.\n(Woman): Why don't we look at it together? Two heads are better than one.",
        "narrator_thai": "ผู้หญิงแนะนำว่าอะไร?",
        "script_thai": "(Man): ผมจ้องโจทย์เลขข้อนี้มาเป็นชั่วโมงแล้วและยังแก้ไม่ได้เลย\n(Woman): ทำไมเราไม่มาดูด้วยกันล่ะ? สองหัวย่อมดีกว่าหัวเดียวนะ",
        "choices_eng": [
            "(A) He should solve it alone.",
            "(B) They should ask the professor.",
            "(C) They should work on the problem together.",
            "(D) He needs to study harder."
        ],
        "choices_thai": [
            "(เขาควรแก้โจทย์คนเดียว)",
            "(พวกเขาควรไปถามอาจารย์)",
            "(พวกเขาควรช่วยกันทำโจทย์ข้อนี้)",
            "(เขาต้องเรียนให้หนักขึ้น)"
        ],
        "answer_text": "เฉลย: (C)\nอธิบาย: สำนวน 'Two heads are better than one' หมายถึง การช่วยกันคิดดีกว่าคิดคนเดียว (Work together)"
    },
    {
        "id": 4,
        "narrator": "What does the man imply about the meeting?",
        "script_eng": "(Woman): Where is everyone? The meeting was supposed to start at 2 PM.\n(Man): Didn't you get the memo? It's been rescheduled for Friday.",
        "narrator_thai": "ผู้ชายบอกเป็นนัยเกี่ยวกับการประชุมว่าอย่างไร?",
        "script_thai": "(Woman): ทุกคนไปไหนกันหมด? การประชุมน่าจะเริ่มตอนบ่าย 2 โมงนี่นา\n(Man): คุณไม่ได้รับบันทึกข้อความเหรอ? มันถูกเลื่อนไปเป็นวันศุกร์แล้วนะ",
        "choices_eng": [
            "(A) The meeting is happening now.",
            "(B) Everyone is late.",
            "(C) The meeting has been postponed.",
            "(D) They are in the wrong room."
        ],
        "choices_thai": [
            "(การประชุมกำลังดำเนินอยู่)",
            "(ทุกคนมาสาย)",
            "(การประชุมถูกเลื่อนออกไป)",
            "(พวกเขาอยู่ผิดห้อง)"
        ],
        "answer_text": "เฉลย: (C)\nอธิบาย: เขาบอกว่า 'rescheduled for Friday' หมายถึงมีการเปลี่ยนเวลาหรือเลื่อนออกไป (Postponed)"
    },
    {
        "id": 5,
        "narrator": "What implies about the man's situation?",
        "script_eng": "(Man): My computer crashed this morning and I lost my entire term paper.\n(Woman): Oh no! Did you have a backup saved on an external drive?\n(Man): Unfortunately, no.",
        "narrator_thai": "บทสนทนาบอกอะไรเกี่ยวกับสถานการณ์ของผู้ชาย?",
        "script_thai": "(Man): คอมพิวเตอร์ผมพังเมื่อเช้า แล้วรายงานเทอมนี้หายเกลี้ยงเลย\n(Woman): แย่จริง! คุณได้สำรองข้อมูลไว้ในไดรฟ์แยกไหม?\n(Man): โชคร้ายที่ไม่ได้ทำไว้",
        "choices_eng": [
            "(A) He can easily recover the file.",
            "(B) He has to start over from the beginning.",
            "(C) He submitted the paper yesterday.",
            "(D) The woman will write it for him."
        ],
        "choices_thai": [
            "(เขาสามารถกู้ไฟล์คืนได้ง่ายๆ)",
            "(เขาต้องเริ่มทำใหม่ตั้งแต่ต้น)",
            "(เขาส่งรายงานไปเมื่อวานแล้ว)",
            "(ผู้หญิงจะเขียนรายงานให้เขา)"
        ],
        "answer_text": "เฉลย: (B)\nอธิบาย: ในเมื่อไฟล์หายและไม่มี Backup (สำรองข้อมูล) นัยที่ตามมาคือเขาต้องเริ่มทำใหม่ทั้งหมด (Start over/Back to square one)"
    },
    {
        "id": 6,
        "narrator": "What does the woman mean?",
        "script_eng": "(Man): Are you coming to the basketball game tonight?\n(Woman): I’d love to, but I have a history exam tomorrow morning and I haven’t even cracked a book yet.",
        "narrator_thai": "ผู้หญิงหมายความว่าอย่างไร?",
        "script_thai": "(Man): คืนนี้คุณจะไปดูแข่งบาสเกตบอลไหม?\n(Woman): อยากไปนะ แต่ฉันมีสอบประวัติศาสตร์พรุ่งนี้เช้า และยังไม่ได้แตะหนังสือเลยสักหน้า",
        "choices_eng": [
            "(A) She broke her history book.",
            "(B) She will go to the game.",
            "(C) She needs to study.",
            "(D) She has already studied enough."
        ],
        "choices_thai": [
            "(เธอทำหนังสือประวัติศาสตร์ขาด)",
            "(เธอจะไปดูการแข่งขัน)",
            "(เธอจำเป็นต้องอ่านหนังสือสอบ)",
            "(เธออ่านหนังสือพอแล้ว)"
        ],
        "answer_text": "เฉลย: (C)\nอธิบาย: สำนวน 'haven't cracked a book' แปลว่า ยังไม่ได้เปิดหนังสือ/ยังไม่ได้เริ่มอ่าน ดังนั้นเธอจึงต้องอยู่ทบทวนบทเรียน (Need to study)"
    },
    {
        "id": 7,
        "narrator": "What does the man suggest the woman do?",
        "script_eng": "(Woman): This soup is stone cold. I can't eat this.\n(Man): I see the waiter over there. Why don't you flag him down?",
        "narrator_thai": "ผู้ชายแนะนำให้ผู้หญิงทำอะไร?",
        "script_thai": "(Woman): ซุปถ้วยนี้เย็นชืดเลย ฉันกินไม่ลงหรอก\n(Man): ผมเห็นบริกรอยู่ตรงนั้น ทำไมคุณไม่เรียกเขามาล่ะ",
        "choices_eng": [
            "(A) Eat the soup anyway.",
            "(B) Leave the restaurant.",
            "(C) Call the waiter.",
            "(D) Cook her own soup."
        ],
        "choices_thai": [
            "(กินซุปไปเถอะ)",
            "(ออกจากร้านอาหาร)",
            "(เรียกบริกร)",
            "(ทำซุปกินเอง)"
        ],
        "answer_text": "เฉลย: (C)\nอธิบาย: สำนวน 'flag him down' หมายถึง การโบกมือเรียกหรือส่งสัญญาณให้หยุด ในที่นี้คือให้เรียกบริกร (Call the waiter) เพื่อแจ้งปัญหา"
    },
    {
        "id": 8,
        "narrator": "What does the woman imply?",
        "script_eng": "(Man): I’m thinking of dropping Dr. Evans’ class. The workload is too heavy.\n(Woman): You’d better check the academic calendar. I think the deadline to drop without penalty was yesterday.",
        "narrator_thai": "ผู้หญิงบอกเป็นนัยว่าอะไร?",
        "script_thai": "(Man): ผมกำลังคิดว่าจะถอนวิชาของ ดร.อีแวนส์ งานมันหนักเกินไป\n(Woman): คุณควรเช็คปฏิทินการศึกษานะ ฉันคิดว่ากำหนดวันสุดท้ายที่จะถอนได้โดยไม่เสียค่าปรับคือเมื่อวานนี้",
        "choices_eng": [
            "(A) It is too late to drop the class.",
            "(B) He should drop the class today.",
            "(C) Dr. Evans is a lenient professor.",
            "(D) The deadline is tomorrow."
        ],
        "choices_thai": [
            "(มันสายเกินไปแล้วที่จะถอนวิชา)",
            "(เขาควรถอนวิชาวันนี้เลย)",
            "(ดร.อีแวนส์ เป็นอาจารย์ที่ใจดี)",
            "(วันกำหนดส่งคือพรุ่งนี้)"
        ],
        "answer_text": "เฉลย: (A)\nอธิบาย: ถ้าเดดไลน์คือ 'yesterday' (เมื่อวาน) แสดงว่าวันนี้มันเลยกำหนดไปแล้ว (Too late)"
    },
    {
        "id": 9,
        "narrator": "What does the man mean?",
        "script_eng": "(Woman): Did you hear that John got the promotion over Steve?\n(Man): You could have knocked me over with a feather! I was sure Steve was going to get it.",
        "narrator_thai": "ผู้ชายหมายความว่าอย่างไร?",
        "script_thai": "(Woman): คุณได้ข่าวไหมว่าจอห์นได้เลื่อนตำแหน่งแทนที่จะเป็นสตีฟ?\n(Man): ผมช็อกไปเลย! (คุณเอาขนนกมาผลักผมก็ล้มแล้ว) ผมมั่นใจมากว่าสตีฟจะได้ตำแหน่งนี้",
        "choices_eng": [
            "(A) He is extremely surprised.",
            "(B) He is very weak.",
            "(C) He knew John would get the job.",
            "(D) He likes feathers."
        ],
        "choices_thai": [
            "(เขารู้สึกประหลาดใจอย่างมาก)",
            "(เขาร่างกายอ่อนแอมาก)",
            "(เขารู้อยู่แล้วว่าจอห์นจะได้งาน)",
            "(เขาชอบขนนก)"
        ],
        "answer_text": "เฉลย: (A)\nอธิบาย: สำนวน 'knock someone over with a feather' ใช้เปรียบเปรยเมื่อรู้สึกตกใจหรือประหลาดใจมากๆ (Extremely surprised) กับเรื่องที่ไม่คาดคิด"
    },
    {
        "id": 10,
        "narrator": "What will the woman probably do?",
        "script_eng": "(Man): I have two extra tickets to the concert tonight. Do you and your sister want to go?\n(Woman): Are you pulling my leg? We’ve been dying to see that band!",
        "narrator_thai": "ผู้หญิงน่าจะทำอะไร?",
        "script_thai": "(Man): ผมมีตั๋วคอนเสิร์ตเหลือ 2 ใบสำหรับคืนนี้ คุณกับน้องสาวอยากไปไหม?\n(Woman): คุณล้อฉันเล่นหรือเปล่าเนี่ย? (พูดด้วยความดีใจ) เราอยากดูวงนี้ใจจะขาดอยู่แล้ว!",
        "choices_eng": [
            "(A) Refuse the tickets.",
            "(B) Pull the man's leg.",
            "(C) Accept the tickets enthusiastically.",
            "(D) Stay home."
        ],
        "choices_thai": [
            "(ปฏิเสธตั๋ว)",
            "(ดึงขาผู้ชาย)",
            "(ตอบรับตั๋วอย่างกระตือรือร้น)",
            "(อยู่บ้าน)"
        ],
        "answer_text": "เฉลย: (C)\nอธิบาย: แม้จะถามว่า 'pulling my leg?' (ล้อเล่นหรือเปล่า) แต่บริบทต่อมาคือ 'dying to see' (อยากดูมากๆ) แสดงความดีใจและตอบรับ (Accept)"
    }
]

# %%
#set 9
questions_data = [
    {
        "id": 1,
        "narrator": "What does the woman imply?",
        "script_eng": "(Man): I’d like to return this sweater. It’s a bit too small.\n(Woman): I can help you with that, provided you have the original receipt.",
        "narrator_thai": "ผู้หญิงบอกเป็นนัยว่าอะไร?",
        "script_thai": "(Man): ผมอยากจะคืนเสื้อกันหนาวตัวนี้ครับ มันเล็กไปหน่อย\n(Woman): ฉันช่วยคุณได้ค่ะ แต่มีข้อแม้ว่าคุณต้องมีใบเสร็จตัวจริงมาด้วยนะ",
        "choices_eng": [
            "(A) She cannot help him.",
            "(B) He can return the sweater if he has the receipt.",
            "(C) The receipt is inside the sweater.",
            "(D) He should buy a larger size."
        ],
        "choices_thai": [
            "(เธอไม่สามารถช่วยเขาได้)",
            "(เขาสามารถคืนเสื้อได้ถ้ามีใบเสร็จ)",
            "(ใบเสร็จอยู่ในเสื้อกันหนาว)",
            "(เขาควรซื้อไซส์ที่ใหญ่กว่า)"
        ],
        "answer_text": "เฉลย: (B)\nอธิบาย: วลี 'provided you have...' หมายถึง 'ถ้าหากว่าคุณมี...' (If/On condition that) ดังนั้นเงื่อนไขการคืนของคือต้องมีใบเสร็จ"
    },
    {
        "id": 2,
        "narrator": "What does the man mean?",
        "script_eng": "(Woman): I was worried about the history exam, but it wasn't too bad.\n(Man): Really? I thought it was a piece of cake.",
        "narrator_thai": "ผู้ชายหมายความว่าอย่างไร?",
        "script_thai": "(Woman): ฉันกังวลเรื่องสอบประวัติศาสตร์มากเลย แต่ก็ไม่ได้แย่เท่าไหร่นะ\n(Man): จริงเหรอ? ผมคิดว่ามันง่ายเหมือนปอกกล้วยเข้าปากเลย (ง่ายมาก)",
        "choices_eng": [
            "(A) He was hungry during the exam.",
            "(B) He brought a cake to the exam.",
            "(C) The exam was extremely difficult.",
            "(D) The exam was very easy."
        ],
        "choices_thai": [
            "(เขาหิวระหว่างสอบ)",
            "(เขาเอาเค้กเข้าไปในห้องสอบ)",
            "(ข้อสอบยากมากๆ)",
            "(ข้อสอบง่ายมากๆ)"
        ],
        "answer_text": "เฉลย: (D)\nอธิบาย: สำนวน 'a piece of cake' แปลว่า ง่ายมากๆ (Very easy)"
    },
    {
        "id": 3,
        "narrator": "What does the woman suggest?",
        "script_eng": "(Man): Look at this traffic! We're going to miss the opening credits.\n(Woman): We might as well get off at the next exit and take the back roads.",
        "narrator_thai": "ผู้หญิงแนะนำว่าอะไร?",
        "script_thai": "(Man): ดูรถติดนี่สิ! เราต้องพลาดเครดิตเปิดเรื่อง (หนังเริ่ม) แน่ๆ เลย\n(Woman): เราลงทางออกข้างหน้าแล้วใช้ทางลัดด้านหลังกันดีกว่า (ทำแบบนั้นก็ได้นะ/ทำแบบนั้นดีกว่า)",
        "choices_eng": [
            "(A) Drive faster on the highway.",
            "(B) Turn around and go home.",
            "(C) Take a different route.",
            "(D) Wait for the traffic to clear."
        ],
        "choices_thai": [
            "(ขับให้เร็วขึ้นบนทางด่วน)",
            "(เลี้ยวรถกลับบ้าน)",
            "(ใช้เส้นทางอื่น)",
            "(รอให้รถหายติด)"
        ],
        "answer_text": "เฉลย: (C)\nอธิบาย: ผู้หญิงแนะนำให้ 'take the back roads' ซึ่งหมายถึงการเปลี่ยนไปใช้เส้นทางอื่น (Different route) เพื่อเลี่ยงรถติด"
    },
    {
        "id": 4,
        "narrator": "What implies about the man?",
        "script_eng": "(Woman): Did you hear that Professor Davis is retiring next month?\n(Man): That's news to me! I just spoke to him yesterday and he didn't mention a thing.",
        "narrator_thai": "บทสนทนาบอกอะไรเกี่ยวกับผู้ชาย?",
        "script_thai": "(Woman): คุณได้ยินไหมว่าศาสตราจารย์เดวิสจะเกษียณเดือนหน้า?\n(Man): นั่นเป็นข่าวใหม่สำหรับผมเลย! (เพิ่งรู้นี่แหละ) ผมเพิ่งคุยกับเขาเมื่อวานเขาไม่เห็นพูดถึงเลยสักนิด",
        "choices_eng": [
            "(A) He already knew about the retirement.",
            "(B) He reads the news every day.",
            "(C) He was unaware of the retirement.",
            "(D) He wants the professor to retire."
        ],
        "choices_thai": [
            "(เขารู้เรื่องเกษียณอยู่แล้ว)",
            "(เขาอ่านข่าวทุกวัน)",
            "(เขาไม่รู้เรื่องการเกษียณมาก่อน)",
            "(เขาอยากให้อาจารย์เกษียณ)"
        ],
        "answer_text": "เฉลย: (C)\nอธิบาย: สำนวน 'That's news to me' แปลว่า เพิ่งเคยได้ยินเป็นครั้งแรก หรือ ไม่รู้เรื่องนี้มาก่อน (Unaware)"
    },
    {
        "id": 5,
        "narrator": "What does the woman offer to do?",
        "script_eng": "(Man): My car is in the shop again. I don't know how I'm going to get to the meeting.\n(Woman): I'm heading that way. I can give you a lift if you want.",
        "narrator_thai": "ผู้หญิงเสนอตัวทำอะไร?",
        "script_thai": "(Man): รถผมเข้าอู่ซ่อมอีกแล้ว ไม่รู้จะไปประชุมยังไงเลยเนี่ย\n(Woman): ฉันกำลังจะไปทางนั้นพอดี ฉันขับรถไปส่งคุณได้นะถ้าคุณต้องการ",
        "choices_eng": [
            "(A) Fix his car.",
            "(B) Drive him to the meeting.",
            "(C) Call a taxi for him.",
            "(D) Cancel the meeting."
        ],
        "choices_thai": [
            "(ซ่อมรถให้เขา)",
            "(ขับรถไปส่งเขาที่ประชุม)",
            "(เรียกแท็กซี่ให้เขา)",
            "(ยกเลิกการประชุม)"
        ],
        "answer_text": "เฉลย: (B)\nอธิบาย: สำนวน 'give you a lift' หรือ 'give you a ride' แปลว่า ให้ติดรถไปด้วย หรือขับรถไปส่ง (Drive him)"
    },
    {
        "id": 6,
        "narrator": "What does the man mean?",
        "script_eng": "(Woman): Can you believe John is late for the presentation again?\n(Man): What else is new? He's never on time.",
        "narrator_thai": "ผู้ชายหมายความว่าอย่างไร?",
        "script_thai": "(Woman): ไม่อยากเชื่อเลยว่าจอห์นมาพรีเซนต์งานสายอีกแล้ว\n(Man): มีอะไรแปลกใหม่ด้วยเหรอ? (มันก็เรื่องปกตินี่) เขาไม่เคยตรงเวลาอยู่แล้ว",
        "choices_eng": [
            "(A) He wants to hear some news.",
            "(B) He is surprised John is late.",
            "(C) He expects John to be late.",
            "(D) John is usually on time."
        ],
        "choices_thai": [
            "(เขาอยากฟังข่าว)",
            "(เขาประหลาดใจที่จอห์นมาสาย)",
            "(เขาคาดไว้อยู่แล้วว่าจอห์นจะมาสาย)",
            "(ปกติจอห์นเป็นคนตรงต่อเวลา)"
        ],
        "answer_text": "เฉลย: (C)\nอธิบาย: วลี 'What else is new?' ใช้ประชดว่าเรื่องนี้ไม่ใช่เรื่องใหม่ หรือเป็นเรื่องปกติที่รู้อยู่แล้ว (Expects it)"
    },
    {
        "id": 7,
        "narrator": "What does the woman imply?",
        "script_eng": "(Man): Are you free to help me move some furniture this Saturday?\n(Woman): I’d love to help, but I’m swamped with midterms right now.",
        "narrator_thai": "ผู้หญิงบอกเป็นนัยว่าอะไร?",
        "script_thai": "(Man): เสาร์นี้คุณว่างมาช่วยผมย้ายเฟอร์นิเจอร์ไหม?\n(Woman): ฉันอยากช่วยนะ แต่ตอนนี้ฉันงานท่วมหัว (ยุ่งมาก) กับการสอบกลางภาคเลย",
        "choices_eng": [
            "(A) She will help him on Sunday.",
            "(B) She is too busy to help.",
            "(C) She has a lot of furniture.",
            "(D) She wants to move out."
        ],
        "choices_thai": [
            "(เธอจะมาช่วยวันอาทิตย์)",
            "(เธอยุ่งเกินกว่าจะช่วยได้)",
            "(เธอมีเฟอร์นิเจอร์เยอะมาก)",
            "(เธออยากย้ายออก)"
        ],
        "answer_text": "เฉลย: (B)\nอธิบาย: คำว่า 'swamped' หมายถึง ยุ่งมากๆ (Too busy) จนปลีกตัวไม่ได้"
    },
    {
        "id": 8,
        "narrator": "What does the man mean?",
        "script_eng": "(Woman): Let's go check out that new French restaurant downtown tonight.\n(Man): I'm a little strapped for cash until payday. Maybe next week?",
        "narrator_thai": "ผู้ชายหมายความว่าอย่างไร?",
        "script_thai": "(Woman): คืนนี้ไปลองร้านอาหารฝรั่งเศสเปิดใหม่ในเมืองกันเถอะ\n(Man): ผมค่อนข้างช็อต (เงินขาดมือ) จนกว่าจะถึงวันเงินเดือนออก อาทิตย์หน้าดีไหม?",
        "choices_eng": [
            "(A) He has plenty of money.",
            "(B) He doesn't like French food.",
            "(C) He is short of money.",
            "(D) He wants to pay with a credit card."
        ],
        "choices_thai": [
            "(เขามีเงินเหลือเฟือ)",
            "(เขาไม่ชอบอาหารฝรั่งเศส)",
            "(เขาขาดแคลนเงิน/เงินไม่พอ)",
            "(เขาอยากจ่ายด้วยบัตรเครดิต)"
        ],
        "answer_text": "เฉลย: (C)\nอธิบาย: สำนวน 'strapped for cash' แปลว่า มีเงินไม่พอ หรือเงินขาดมือ (Short of money)"
    },
    {
        "id": 9,
        "narrator": "What does the woman imply about Dr. Lee?",
        "script_eng": "(Man): I need to get Dr. Lee's signature on my thesis proposal.\n(Woman): You'll have to wait. He's out of town for a conference until Monday.",
        "narrator_thai": "ผู้หญิงบอกเป็นนัยเกี่ยวกับดร.ลีว่าอย่างไร?",
        "script_thai": "(Man): ผมต้องให้ดร.ลีเซ็นชื่อในหัวข้อวิทยานิพนธ์ของผม\n(Woman): คุณคงต้องรอหน่อยนะ เขาไปงานประชุมต่างเมืองจนถึงวันจันทร์นู่นเลย",
        "choices_eng": [
            "(A) He is in his office.",
            "(B) He is currently unavailable.",
            "(C) He will not sign the proposal.",
            "(D) He moved to another town."
        ],
        "choices_thai": [
            "(เขาอยู่ในห้องทำงาน)",
            "(ตอนนี้เขาไม่ว่าง/ไม่อยู่)",
            "(เขาจะไม่ยอมเซ็นหัวข้อวิทยานิพนธ์)",
            "(เขาย้ายไปอยู่เมืองอื่น)"
        ],
        "answer_text": "เฉลย: (B)\nอธิบาย: การที่เขา 'out of town' (อยู่ต่างเมือง) หมายความว่าเขาไม่สามารถมาเซ็นให้ได้ในขณะนี้ (Unavailable)"
    },
    {
        "id": 10,
        "narrator": "What does the man mean?",
        "script_eng": "(Woman): Do you think the boss will approve our request for new computers?\n(Man): Don't hold your breath. The budget is really tight this year.",
        "narrator_thai": "ผู้ชายหมายความว่าอย่างไร?",
        "script_thai": "(Woman): คุณคิดว่าหัวหน้าจะอนุมัติคำขอซื้อคอมพิวเตอร์ใหม่ของพวกเราไหม?\n(Man): อย่าไปคาดหวังเลย (อย่ากลั้นหายใจรอ) ปีนี้งบประมาณจำกัดมากๆ",
        "choices_eng": [
            "(A) He thinks it is very likely.",
            "(B) He suggests asking again later.",
            "(C) He thinks it is unlikely to happen.",
            "(D) He is having trouble breathing."
        ],
        "choices_thai": [
            "(เขาคิดว่ามีโอกาสสูงมาก)",
            "(เขาแนะนำให้มาขอใหม่วันหลัง)",
            "(เขาคิดว่าไม่น่าจะเป็นไปได้)",
            "(เขากำลังหายใจติดขัด)"
        ],
        "answer_text": "เฉลย: (C)\nอธิบาย: สำนวน 'Don't hold your breath' ใช้บอกว่าสิ่งนั้นไม่น่าจะเกิดขึ้น หรืออย่าไปตั้งความหวังไว้สูง (Unlikely to happen)"
    }
]

# %%
#set 10
questions_data = [
    {
        "id": 1,
        "narrator": "What does the woman mean?",
        "script_eng": "(Man): That biology exam was absolutely exhausting.\n(Woman): You can say that again! My brain is fried.",
        "narrator_thai": "ผู้หญิงหมายความว่าอย่างไร?",
        "script_thai": "(Man): ข้อสอบชีววิทยานั่นทำเอาหมดแรงสุดๆ ไปเลย\n(Woman): พูดอีกก็ถูกอีก! (เห็นด้วยที่สุด) สมองฉันไหม้ไปหมดแล้ว",
        "choices_eng": [
            "(A) She wants the man to repeat what he said.",
            "(B) She disagrees with the man.",
            "(C) She agrees completely with the man.",
            "(D) She wants to take the exam again."
        ],
        "choices_thai": [
            "(เธออยากให้ผู้ชายพูดซ้ำ)",
            "(เธอไม่เห็นด้วยกับผู้ชาย)",
            "(เธอเห็นด้วยกับผู้ชายอย่างยิ่ง)",
            "(เธออยากสอบใหม่อีกรอบ)"
        ],
        "answer_text": "เฉลย: (C)\nอธิบาย: สำนวน 'You can say that again' ไม่ได้แปลว่าให้พูดซ้ำ แต่แปลว่า 'เห็นด้วยอย่างยิ่ง' (Agrees completely)"
    },
    {
        "id": 2,
        "narrator": "What does the man imply about the laptop?",
        "script_eng": "(Woman): I’m thinking of buying this laptop, but it’s a bit pricey.\n(Man): Well, you get what you pay for. It will last you a lot longer than the cheaper ones.",
        "narrator_thai": "ผู้ชายบอกเป็นนัยเกี่ยวกับแล็ปท็อปว่าอย่างไร?",
        "script_thai": "(Woman): ฉันกำลังคิดว่าจะซื้อแล็ปท็อปเครื่องนี้ แต่มันแพงไปหน่อย\n(Man): ก็นะ คุณจ่ายเท่าไหร่ก็ได้เท่านั้นแหละ (ของแพงก็ย่อมดีกว่า) มันจะอยู่ทนกว่าพวกเครื่องถูกๆ เยอะเลย",
        "choices_eng": [
            "(A) It is too expensive.",
            "(B) It is worth the high price.",
            "(C) The cheaper ones are better.",
            "(D) He will pay for it."
        ],
        "choices_thai": [
            "(มันแพงเกินไป)",
            "(มันคุ้มค่ากับราคาที่สูง)",
            "(เครื่องที่ถูกกว่านั้นดีกว่า)",
            "(เขาจะเป็นคนจ่ายเงินเอง)"
        ],
        "answer_text": "เฉลย: (B)\nอธิบาย: สำนวน 'you get what you pay for' และการบอกว่ามันทนทานกว่า (last longer) เป็นนัยว่าคุ้มค่าที่จะจ่าย (Worth the price)"
    },
    {
        "id": 3,
        "narrator": "What implies about the woman?",
        "script_eng": "(Man): Are you ready for your presentation speech tomorrow?\n(Woman): To be honest, I have butterflies in my stomach just thinking about it.",
        "narrator_thai": "บทสนทนาบอกอะไรเกี่ยวกับผู้หญิง?",
        "script_thai": "(Man): คุณพร้อมสำหรับการพูดนำเสนอพรุ่งนี้หรือยัง?\n(Woman): พูดตรงๆ นะ แค่คิดฉันก็รู้สึกมวนท้อง (ตื่นเต้น/ประหม่า) แล้วเนี่ย",
        "choices_eng": [
            "(A) She is hungry.",
            "(B) She is excited and confident.",
            "(C) She is sick.",
            "(D) She is very nervous."
        ],
        "choices_thai": [
            "(เธอหิวข้าว)",
            "(เธอตื่นเต้นและมั่นใจ)",
            "(เธอป่วย)",
            "(เธอรู้สึกประหม่า/กังวลมาก)"
        ],
        "answer_text": "เฉลย: (D)\nอธิบาย: สำนวน 'have butterflies in my stomach' หมายถึง อาการประหม่าหรือตื่นเต้นจนท้องไส้ปั่นป่วน (Nervous) มักใช้ก่อนขึ้นแสดงหรือพูด"
    },
    {
        "id": 4,
        "narrator": "What does the man suggest?",
        "script_eng": "(Woman): I signed up for six classes this semester, and I'm also working part-time.\n(Man): It sounds like you might be biting off more than you can chew.",
        "narrator_thai": "ผู้ชายแนะนำ/เตือนว่าอะไร?",
        "script_thai": "(Woman): เทอมนี้ฉันลงเรียนไป 6 วิชา แถมยังทำงานพาร์ทไทม์ด้วย\n(Man): ฟังดูเหมือนคุณกำลังทำอะไรเกินตัวอยู่นะ",
        "choices_eng": [
            "(A) She should eat more.",
            "(B) She should quit her job immediately.",
            "(C) She is taking on too much responsibility.",
            "(D) She should take more classes."
        ],
        "choices_thai": [
            "(เธอควรกินให้เยอะขึ้น)",
            "(เธอควรลาออกจากงานทันที)",
            "(เธอกำลังแบกรับภาระมากเกินไป)",
            "(เธอควรลงเรียนเพิ่มอีก)"
        ],
        "answer_text": "เฉลย: (C)\nอธิบาย: สำนวน 'bite off more than you can chew' (กัดคำใหญ่เกินกว่าจะเคี้ยวไหว) หมายถึง การรับภาระหรือทำงานเกินกำลังที่ตัวเองจะทำไหว (Too much responsibility)"
    },
    {
        "id": 5,
        "narrator": "What does the woman imply?",
        "script_eng": "(Man): How was the new Italian restaurant downtown?\n(Woman): Well, let’s just say I’ve had better frozen pizza.",
        "narrator_thai": "ผู้หญิงบอกเป็นนัยว่าอะไร?",
        "script_thai": "(Man): ร้านอาหารอิตาเลียนร้านใหม่ในเมืองเป็นยังไงบ้าง?\n(Man): อืม เอาเป็นว่าพิซซ่าแช่แข็งที่ฉันเคยกินยังอร่อยกว่าเลย",
        "choices_eng": [
            "(A) The restaurant was excellent.",
            "(B) She prefers frozen food.",
            "(C) The food was terrible.",
            "(D) She wants to go back."
        ],
        "choices_thai": [
            "(ร้านอาหารยอดเยี่ยมมาก)",
            "(เธอชอบอาหารแช่แข็งมากกว่า)",
            "(อาหารรสชาติแย่มาก)",
            "(เธออยากกลับไปอีก)"
        ],
        "answer_text": "เฉลย: (C)\nอธิบาย: การเปรียบเทียบว่า 'frozen pizza' (อาหารแช่แข็ง) ยังดีกว่า เป็นการตำหนิอย่างรุนแรงว่าอาหารที่ร้านนั้นไม่อร่อยเลย (Terrible)"
    },
    {
        "id": 6,
        "narrator": "What will the man probably do?",
        "script_eng": "(Woman): I can't find my keys anywhere. I'm going to be late for work!\n(Man): Retrace your steps. When was the last time you saw them?",
        "narrator_thai": "ผู้ชายน่าจะทำอะไร (หรือแนะนำให้ทำอะไร)?",
        "script_thai": "(Woman): ฉันหากุญแจไม่เจอเลย ฉันจะไปทำงานสายแล้วเนี่ย!\n(Man): ลองย้อนนึกดูสิ ครั้งสุดท้ายที่คุณเห็นมันคือเมื่อไหร่?",
        "choices_eng": [
            "(A) Drive the woman to work.",
            "(B) Help her look for the keys.",
            "(C) Buy new keys.",
            "(D) Call her boss."
        ],
        "choices_thai": [
            "(ขับรถไปส่งผู้หญิงที่ทำงาน)",
            "(ช่วยเธอหากุญแจ)",
            "(ซื้อกุญแจดอกใหม่)",
            "(โทรหาเจ้านายของเธอ)"
        ],
        "answer_text": "เฉลย: (B)\nอธิบาย: แม้ในบทพูดเขาจะแค่แนะนำให้ 'Retrace your steps' แต่ตามบริบทธรรมชาติของการสนทนา เขาพยายามช่วยเธอแก้ปัญหาการหาของ (Help look for keys)"
    },
    {
        "id": 7,
        "narrator": "What does the woman mean?",
        "script_eng": "(Man): Did you finish the project on time?\n(Woman): Just barely. It really came down to the wire.",
        "narrator_thai": "ผู้หญิงหมายความว่าอย่างไร?",
        "script_thai": "(Man): คุณทำโปรเจกต์เสร็จทันเวลาไหม?\n(Woman): เฉียดฉิวเลย มันเสร็จเอาวินาทีสุดท้ายจริงๆ",
        "choices_eng": [
            "(A) She finished it early.",
            "(B) She needed a wire to finish it.",
            "(C) She finished it at the very last moment.",
            "(D) She didn't finish it."
        ],
        "choices_thai": [
            "(เธอทำเสร็จก่อนเวลา)",
            "(เธอต้องใช้ลวดเพื่อทำให้เสร็จ)",
            "(เธอทำเสร็จในนาทีสุดท้ายพอดี)",
            "(เธอทำไม่เสร็จ)"
        ],
        "answer_text": "เฉลย: (C)\nอธิบาย: สำนวน 'down to the wire' หมายถึง จนถึงวินาทีสุดท้าย หรือเฉียดเส้นตายพอดี (At the very last moment)"
    },
    {
        "id": 8,
        "narrator": "What does the man imply?",
        "script_eng": "(Woman): I heard you're moving to Chicago. Are you excited?\n(Man): I have mixed feelings. It's a great opportunity, but I'll miss my friends here.",
        "narrator_thai": "ผู้ชายบอกเป็นนัยว่าอะไร?",
        "script_thai": "(Woman): ได้ข่าวว่าคุณจะย้ายไปชิคาโก ตื่นเต้นไหม?\n(Man): ผมรู้สึกสับสนนะ (Mixed feelings) มันเป็นโอกาสที่ดี แต่ผมคงคิดถึงเพื่อนๆ ที่นี่",
        "choices_eng": [
            "(A) He is definitely not going.",
            "(B) He is happy to leave his friends.",
            "(C) He is unsure if he made the right choice.",
            "(D) He is both happy and sad about the move."
        ],
        "choices_thai": [
            "(เขาจะไม่ไปแน่นอน)",
            "(เขาดีใจที่จะได้จากเพื่อนๆ ไป)",
            "(เขาไม่แน่ใจว่าเลือกถูกหรือเปล่า)",
            "(เขาทั้งดีใจและเสียใจเกี่ยวกับการย้าย)"
        ],
        "answer_text": "เฉลย: (D)\nอธิบาย: 'Mixed feelings' หมายถึงความรู้สึกผสมปนเปกัน ในที่นี้คือดีใจกับโอกาส (happy) แต่เสียใจที่ต้องจากเพื่อน (sad)"
    },
    {
        "id": 9,
        "narrator": "What does the woman suggest?",
        "script_eng": "(Man): This rain is never going to stop. I guess we have to cancel the picnic.\n(Woman): Don't throw in the towel yet. The forecast says it might clear up by noon.",
        "narrator_thai": "ผู้หญิงแนะนำว่าอะไร?",
        "script_thai": "(Man): ฝนไม่มีทีท่าว่าจะหยุดเลย สงสัยเราต้องยกเลิกปิกนิกซะแล้ว\n(Woman): อย่าเพิ่งยอมแพ้นะ พยากรณ์อากาศบอกว่าฟ้าอาจจะเปิดตอนเที่ยง",
        "choices_eng": [
            "(A) Cancel the picnic immediately.",
            "(B) Throw away the towels.",
            "(C) Wait a little longer before canceling.",
            "(D) Go for a swim in the rain."
        ],
        "choices_thai": [
            "(ยกเลิกปิกนิกทันที)",
            "(โยนผ้าเช็ดตัวทิ้ง)",
            "(รออีกสักหน่อยก่อนค่อยยกเลิก)",
            "(ออกไปว่ายน้ำท่ามกลางสายฝน)"
        ],
        "answer_text": "เฉลย: (C)\nอธิบาย: สำนวน 'throw in the towel' (โยนผ้าขาว) มาจากมวย แปลว่า ยอมแพ้ เธอจึงบอกว่าอย่าเพิ่งยอมแพ้ ให้รอดูก่อน (Wait a little longer)"
    },
    {
        "id": 10,
        "narrator": "What does the man mean?",
        "script_eng": "(Woman): Can I borrow your car tomorrow? Mine is in the shop.\n(Man): Sorry, but I need it to get to a job interview. Otherwise, I would.",
        "narrator_thai": "ผู้ชายหมายความว่าอย่างไร?",
        "script_thai": "(Woman): พรุ่งนี้ขอยืมรถคุณหน่อยได้ไหม? รถฉันเข้าอู่หน่ะ\n(Man): ขอโทษที แต่ผมต้องใช้รถขับไปสัมภาษณ์งาน ไม่อย่างนั้นผมคงให้ยืมแล้ว",
        "choices_eng": [
            "(A) He doesn't want to lend her the car.",
            "(B) He would lend it if he didn't need it.",
            "(C) His car is also in the shop.",
            "(D) He will drive her to work."
        ],
        "choices_thai": [
            "(เขาไม่อยากให้เธอยืมรถ)",
            "(เขาจะให้ยืมถ้าเขาไม่จำเป็นต้องใช้)",
            "(รถของเขาก็เข้าอู่เหมือนกัน)",
            "(เขาจะขับรถไปส่งเธอที่ทำงาน)"
        ],
        "answer_text": "เฉลย: (B)\nอธิบาย: วลี 'Otherwise, I would' (ถ้าไม่ติดเรื่องนั้น ผมคงทำให้แล้ว) แสดงเจตนาว่าอยากช่วย แต่ติดธุระจริงๆ (Would lend it if he didn't need it)"
    }
]

# %%
# Set 11 ระดับยากกว่า 6 และใส่เทคนิคการเว้นวรรคและเครื่องหมายวรรคตอน (Punctuation Hacks) ลงใน script_eng เพื่อช่วยไกด์ให้ AI ออกเสียงได้สมจริงและใส่อารมณ์มากขึ้น
questions_data = [
    {
        "id": 1,
        "narrator": "What does the man imply?",
        "script_eng": "(Woman): Are you finally going to buy that house you looked at last week?\n(Man): Well... I'm still on the fence. It's a huge investment.",
        "narrator_thai": "ผู้ชายบอกเป็นนัยว่าอะไร?",
        "script_thai": "(Woman): ในที่สุดคุณจะซื้อบ้านหลังที่คุณไปดูเมื่ออาทิตย์ที่แล้วไหม?\n(Man): อืม... ผมยังตัดสินใจไม่ได้เลย (On the fence) มันเป็นการลงทุนที่ใหญ่มากนะ",
        "choices_eng": [
            "(A) He is building a fence around the house.",
            "(B) He has decided not to buy the house.",
            "(C) He has not made a decision yet.",
            "(D) He thinks the house is too expensive."
        ],
        "choices_thai": [
            "(เขากำลังสร้างรั้วรอบบ้าน)",
            "(เขาตัดสินใจแล้วว่าจะไม่ซื้อบ้าน)",
            "(เขายังไม่ได้ตัดสินใจ)",
            "(เขาคิดว่าบ้านแพงเกินไป)"
        ],
        "answer_text": "เฉลย: (C)\nอธิบาย: สำนวน 'on the fence' หมายถึง ลังเลหรือยังตัดสินใจไม่ได้ (Undecided) การใส่ 'Well...' ช่วยสื่อถึงความลังเล"
    },
    {
        "id": 2,
        "narrator": "What does the woman mean?",
        "script_eng": "(Man): I hope the boss doesn't ask me to lead the new project.\n(Woman): Don't worry! I think he has... someone else in mind.",
        "narrator_thai": "ผู้หญิงหมายความว่าอย่างไร?",
        "script_thai": "(Man): ผมหวังว่าหัวหน้าคงไม่ขอให้ผมเป็นคนนำโปรเจกต์ใหม่นะ\n(Woman): อย่ากังวลไปเลย! ฉันคิดว่าเขามีคนอื่นในใจอยู่แล้วล่ะ",
        "choices_eng": [
            "(A) The boss wants the man to lead.",
            "(B) The boss is thinking about another person.",
            "(C) The boss has lost his mind.",
            "(D) The boss will ask the woman."
        ],
        "choices_thai": [
            "(หัวหน้าอยากให้ผู้ชายเป็นคนนำ)",
            "(หัวหน้ากำลังคิดถึงคนอื่นอยู่)",
            "(หัวหน้าเสียสติไปแล้ว)",
            "(หัวหน้าจะขอให้ผู้หญิงทำ)"
        ],
        "answer_text": "เฉลย: (B)\nอธิบาย: วลี 'has someone else in mind' แปลว่า มีตัวเลือกอื่นไว้แล้ว"
    },
    {
        "id": 3,
        "narrator": "What implies about the vacation plans?",
        "script_eng": "(Man): Have you booked the flight for our holiday yet?\n(Woman): Not yet. Everything is still... up in the air... until my leave is approved.",
        "narrator_thai": "บทสนทนาบอกอะไรเกี่ยวกับแผนวันหยุด?",
        "script_thai": "(Man): คุณจองตั๋วเครื่องบินสำหรับวันหยุดของเราหรือยัง?\n(Woman): ยังเลย ทุกอย่างยังไม่แน่นอน (Up in the air) จนกว่าวันลาของฉันจะได้รับการอนุมัติ",
        "choices_eng": [
            "(A) They are flying somewhere soon.",
            "(B) The plans are confirmed.",
            "(C) The plans are uncertain/undecided.",
            "(D) The flight has been canceled."
        ],
        "choices_thai": [
            "(พวกเขากำลังจะบินไปเที่ยวเร็วๆ นี้)",
            "(แผนการได้รับการยืนยันแล้ว)",
            "(แผนการยังไม่แน่นอน/ยังไม่ตัดสินใจ)",
            "(เที่ยวบินถูกยกเลิก)"
        ],
        "answer_text": "เฉลย: (C)\nอธิบาย: สำนวน 'up in the air' หมายถึง ยังลูกผีลูกคน ไม่แน่นอน การใช้ '...' ช่วยเว้นจังหวะให้ดูเหมือนกำลังกังวล"
    },
    {
        "id": 4,
        "narrator": "What does the man suggest the woman do?",
        "script_eng": "(Woman): I’m so nervous about the interview. What if they ask me something I don't know?\n(Man): Just play it by ear! You can't prepare for everything.",
        "narrator_thai": "ผู้ชายแนะนำให้ผู้หญิงทำอะไร?",
        "script_thai": "(Woman): ฉันตื่นเต้นกับการสัมภาษณ์จัง ถ้าเขาถามสิ่งที่ฉันไม่รู้ล่ะ?\n(Man): ก็แค่แก้ปัญหาเฉพาะหน้าไป! (Play it by ear) คุณเตรียมตัวไปทุกอย่างไม่ได้หรอก",
        "choices_eng": [
            "(A) Listen carefully to the questions.",
            "(B) Prepare for every possible question.",
            "(C) Handle the situation as it happens.",
            "(D) Play some music to relax."
        ],
        "choices_thai": [
            "(ตั้งใจฟังคำถาม)",
            "(เตรียมตัวสำหรับทุกคำถามที่เป็นไปได้)",
            "(รับมือกับสถานการณ์ตามหน้างาน)",
            "(เล่นดนตรีเพื่อผ่อนคลาย)"
        ],
        "answer_text": "เฉลย: (C)\nอธิบาย: สำนวน 'play it by ear' หมายถึง ทำไปตามสถานการณ์ เครื่องหมาย '!' ช่วยให้น้ำเสียงดูเป็นการให้กำลังใจ"
    },
    {
        "id": 5,
        "narrator": "What does the woman imply about the car?",
        "script_eng": "(Man): Should we take your car to the mountains?\n(Woman): I wouldn't risk it! It's on its last legs.",
        "narrator_thai": "ผู้หญิงบอกเป็นนัยเกี่ยวกับรถว่าอย่างไร?",
        "script_thai": "(Man): เราเอารถของคุณขึ้นเขาดีไหม?\n(Woman): ฉันจะไม่เสี่ยงนะ! มันใกล้จะพังเต็มทีแล้ว (On its last legs)",
        "choices_eng": [
            "(A) The car is brand new.",
            "(B) The car is in poor condition.",
            "(C) The car runs very fast.",
            "(D) The car has flat tires."
        ],
        "choices_thai": [
            "(รถคันนี้ใหม่เอี่ยม)",
            "(รถอยู่ในสภาพแย่)",
            "(รถวิ่งได้เร็วมาก)",
            "(รถยางแบน)"
        ],
        "answer_text": "เฉลย: (B)\nอธิบาย: สำนวน 'on its last legs' แปลว่า ใกล้พัง การใช้ '!' ช่วยเน้นเสียงเตือนว่าอย่าหาทำ"
    },
    {
        "id": 6,
        "narrator": "What does the man mean?",
        "script_eng": "(Woman): I heard you and Mark had a disagreement about the budget.\n(Man): Yeah... we don't exactly see eye to eye on how to spend the funds.",
        "narrator_thai": "ผู้ชายหมายความว่าอย่างไร?",
        "script_thai": "(Woman): ได้ข่าวว่าคุณกับมาร์คมีความเห็นไม่ตรงกันเรื่องงบประมาณ\n(Man): ใช่... เราเห็นไม่ตรงกันเท่าไหร่หรอก (Don't see eye to eye) ว่าจะใช้เงินยังไง",
        "choices_eng": [
            "(A) They are looking at each other.",
            "(B) They agree on everything.",
            "(C) They have different opinions.",
            "(D) They have vision problems."
        ],
        "choices_thai": [
            "(พวกเขากำลังมองหน้ากัน)",
            "(พวกเขาเห็นด้วยกันทุกเรื่อง)",
            "(พวกเขามีความคิดเห็นที่แตกต่างกัน)",
            "(พวกเขามีปัญหาทางสายตา)"
        ],
        "answer_text": "เฉลย: (C)\nอธิบาย: 'Yeah...' แบบลากเสียงยาว สื่อถึงความเหนื่อยหน่ายใจกับความขัดแย้งนั้น"
    },
    {
        "id": 7,
        "narrator": "What does the woman suggest?",
        "script_eng": "(Man): I promised to help Sarah move, but I have so much homework.\n(Woman): You shouldn't have made a promise you couldn't keep! You can't back out now.",
        "narrator_thai": "ผู้หญิงแนะนำว่าอะไร?",
        "script_thai": "(Man): ผมสัญญาว่าจะไปช่วยซาร่าย้ายของ แต่ผมมีการบ้านเยอะมากเลย\n(Woman): คุณไม่ควรสัญญาในสิ่งที่คุณทำไม่ได้นะ! คุณจะถอนตัวตอนนี้ไม่ได้แล้ว",
        "choices_eng": [
            "(A) He should help Sarah move.",
            "(B) He should do his homework first.",
            "(C) He should walk backwards.",
            "(D) He should apologize and stay home."
        ],
        "choices_thai": [
            "(เขาควรไปช่วยซาร่าย้ายของ)",
            "(เขาควรทำการบ้านก่อน)",
            "(เขาควรเดินถอยหลัง)",
            "(เขาควรขอโทษและอยู่บ้าน)"
        ],
        "answer_text": "เฉลย: (A)\nอธิบาย: การใช้ '!' ในประโยคแรก เป็นการดุหรือตำหนิเสียงแข็ง เพื่อบังคับให้เขารักษาคำพูด"
    },
    {
        "id": 8,
        "narrator": "What does the man imply about the chemistry test?",
        "script_eng": "(Woman): How did the chemistry test go? Did you pass?\n(Man): Pass?! I barely scraped by with a D!",
        "narrator_thai": "ผู้ชายบอกเป็นนัยเกี่ยวกับการสอบเคมีว่าอย่างไร?",
        "script_thai": "(Woman): สอบเคมีเป็นไงบ้าง? ผ่านไหม?\n(Man): ผ่านเหรอ?! (ถามเสียงสูง) ผมแค่ผ่านแบบคาบเส้น (Scraped by) ด้วยเกรด D เอง!",
        "choices_eng": [
            "(A) He failed the test.",
            "(B) He got a very high score.",
            "(C) He passed with a low score.",
            "(D) He dropped the class."
        ],
        "choices_thai": [
            "(เขาสอบตก)",
            "(เขาได้คะแนนสูงมาก)",
            "(เขาสอบผ่านด้วยคะแนนคาบเส้น/ต่ำ)",
            "(เขาถอนรายวิชา)"
        ],
        "answer_text": "เฉลย: (C)\nอธิบาย: เครื่องหมาย '?!' จะทำให้ AI ขึ้นเสียงสูงด้วยความตกใจหรือประชดตัวเอง"
    },
    {
        "id": 9,
        "narrator": "What does the woman mean?",
        "script_eng": "(Man): I’m thinking of asking for a raise today.\n(Woman): I wouldn't do that if I were you! The manager is in a foul mood.",
        "narrator_thai": "ผู้หญิงหมายความว่าอย่างไร?",
        "script_thai": "(Man): ผมกำลังคิดว่าจะไปขอขึ้นเงินเดือนวันนี้\n(Woman): ถ้าฉันเป็นคุณฉันจะไม่ทำนะ! ผู้จัดการกำลังอารมณ์บูดสุดๆ",
        "choices_eng": [
            "(A) The manager is happy today.",
            "(B) It is a bad time to ask for a raise.",
            "(C) The manager wants to give him a raise.",
            "(D) She wants a raise too."
        ],
        "choices_thai": [
            "(วันนี้ผู้จัดการอารมณ์ดี)",
            "(มันเป็นเวลาที่ไม่ดีที่จะขอขึ้นเงินเดือน)",
            "(ผู้จัดการอยากขึ้นเงินเดือนให้เขา)",
            "(เธอก็อยากได้เงินเดือนขึ้นเหมือนกัน)"
        ],
        "answer_text": "เฉลย: (B)\nอธิบาย: เครื่องหมาย '!' ใช้เตือนสติอย่างจริงจังว่า 'อย่าหาทำ'"
    },
    {
        "id": 10,
        "narrator": "What does the man imply?",
        "script_eng": "(Woman): Are you going to finish that report by 5 PM?\n(Man): Only if a miracle happens... I still have ten pages to write!",
        "narrator_thai": "ผู้ชายบอกเป็นนัยว่าอะไร?",
        "script_thai": "(Woman): คุณจะทำรายงานนั่นเสร็จภายใน 5 โมงเย็นไหม?\n(Man): ก็ต่อเมื่อมีปาฏิหาริย์เกิดขึ้นนั่นแหละ... ผมยังเหลือต้องเขียนอีกตั้ง 10 หน้าแน่ะ!",
        "choices_eng": [
            "(A) He will definitely finish on time.",
            "(B) He believes in miracles.",
            "(C) He will likely not finish on time.",
            "(D) He needs ten more minutes."
        ],
        "choices_thai": [
            "(เขาจะทำเสร็จทันเวลาแน่นอน)",
            "(เขาเชื่อในปาฏิหาริย์)",
            "(เขาน่าจะทำเสร็จไม่ทันเวลา)",
            "(เขาต้องการเวลาอีก 10 นาที)"
        ],
        "answer_text": "เฉลย: (C)\nอธิบาย: การใช้ '...' หลังประโยคแรก จะทำให้เสียงแผ่วลงเหมือนคนสิ้นหวัง"
    }
]

# %%
#set 12
questions_data = [
    {
        "id": 1,
        "narrator": "What does the man imply about the watch?",
        "script_eng": "(Woman): Wow! That watch looks incredibly expensive.\n(Man): It sure did! It cost me a pretty penny... but I couldn't resist.",
        "narrator_thai": "ผู้ชายบอกเป็นนัยเกี่ยวกับนาฬิกาว่าอย่างไร?",
        "script_thai": "(Woman): ว้าว! นาฬิกาเรือนนั้นดูแพงมหาศาลเลยนะ\n(Man): ก็แหงล่ะ! มันแพงหูฉี่เลย (Cost a pretty penny)... แต่ผมอดใจไม่ไหวจริงๆ",
        "choices_eng": [
            "(A) It was very cheap.",
            "(B) He found it on the street.",
            "(C) It was very expensive.",
            "(D) He resisted buying it."
        ],
        "choices_thai": [
            "(มันราคาถูกมาก)",
            "(เขาเก็บได้ตามท้องถนน)",
            "(มันราคาแพงมาก)",
            "(เขาอดใจไม่ซื้อได้)"
        ],
        "answer_text": "เฉลย: (C)\nอธิบาย: สำนวน 'cost a pretty penny' แปลว่า มีราคาแพงมาก (Very expensive) การใช้ '...' ช่วยเน้นความรู้สึกเสียดายเงินนิดๆ แต่ก็ภูมิใจ"
    },
    {
        "id": 2,
        "narrator": "What does the woman suggest?",
        "script_eng": "(Man): Did you hear?! They say the cafeteria is giving away free lunch today!\n(Woman): I wouldn't bet on it... You shouldn't believe everything you hear.",
        "narrator_thai": "ผู้หญิงแนะนำว่าอะไร?",
        "script_thai": "(Man): คุณได้ยินไหม?! เขาว่ากันว่าโรงอาหารแจกมื้อเที่ยงฟรีวันนี้!\n(Woman): ฉันไม่เชื่อหรอกนะ (I wouldn't bet on it)... คุณไม่ควรเชื่อทุกอย่างที่ได้ยินหรอก",
        "choices_eng": [
            "(A) Go to the cafeteria immediately.",
            "(B) Be skeptical of the rumor.",
            "(C) Bet money on the lunch.",
            "(D) Listen to everything people say."
        ],
        "choices_thai": [
            "(ไปที่โรงอาหารทันที)",
            "(จงสงสัยในข่าวลือนั้น)",
            "(พนันเงินเรื่องอาหารกลางวัน)",
            "(ฟังทุกอย่างที่คนพูด)"
        ],
        "answer_text": "เฉลย: (B)\nอธิบาย: สำนวน 'I wouldn't bet on it' หมายถึง ไม่น่าจะเป็นไปได้ และเธอเตือนว่าอย่าเชื่อข่าวลือ (Be skeptical)"
    },
    {
        "id": 3,
        "narrator": "What does the woman mean?",
        "script_eng": "(Man): I think I'll study for the physics exam... tomorrow.\n(Woman): Why put it off?! It's better to just get it over with now!",
        "narrator_thai": "ผู้หญิงหมายความว่าอย่างไร?",
        "script_thai": "(Man): ผมคิดว่าผมจะอ่านหนังสือสอบฟิสิกส์... พรุ่งนี้ละกัน\n(Woman): จะผลัดวันประกันพรุ่งไปทำไม?! (Put it off) ทำให้มันจบๆ ไปตอนนี้เลยดีกว่าน่า!",
        "choices_eng": [
            "(A) He should delay studying.",
            "(B) He should study immediately.",
            "(C) He should drop the class.",
            "(D) He should study tomorrow."
        ],
        "choices_thai": [
            "(เขาควรเลื่อนการอ่านหนังสือออกไป)",
            "(เขาควรชิงอ่านหนังสือทันที)",
            "(เขาควรดรอปเรียน)",
            "(เขาควรไปอ่านพรุ่งนี้)"
        ],
        "answer_text": "เฉลย: (B)\nอธิบาย: 'Put off' แปลว่า เลื่อนออกไป เธอถามเชิงตำหนิว่าทำไมต้องเลื่อน และแนะนำให้ 'get it over with' (ทำให้จบๆ ไป) คือให้ทำเลย (Immediately)"
    },
    {
        "id": 4,
        "narrator": "What does the man imply?",
        "script_eng": "(Woman): I am completely overwhelmed by this semester's workload.\n(Man): You're not alone! We're... in the same boat.",
        "narrator_thai": "ผู้ชายบอกเป็นนัยว่าอะไร?",
        "script_thai": "(Woman): ฉันรู้สึกรับมือไม่ไหว (Overwhelmed) กับภาระงานเทอมนี้แล้วเนี่ย\n(Man): คุณไม่ได้ตัวคนเดียวนะ! พวกเรา... ตกที่นั่งลำบากเหมือนกันเปี๊ยบ (In the same boat)",
        "choices_eng": [
            "(A) They are going on a boat trip.",
            "(B) He is facing similar difficulties.",
            "(C) He thinks the work is easy.",
            "(D) He has a different schedule."
        ],
        "choices_thai": [
            "(พวกเขากำลังจะไปล่องเรือ)",
            "(เขากำลังเผชิญความยากลำบากเหมือนกัน)",
            "(เขาคิดว่างานนั้นง่าย)",
            "(เขามีตารางเรียนที่ต่างกัน)"
        ],
        "answer_text": "เฉลย: (B)\nอธิบาย: สำนวน 'in the same boat' แปลว่า ตกอยู่ในสถานการณ์เดียวกัน (โดยเฉพาะสถานการณ์ที่ลำบาก)"
    },
    {
        "id": 5,
        "narrator": "What does the woman mean?",
        "script_eng": "(Man): Did you manage to catch the 8 o'clock train?\n(Woman): Barely! I really cut it close this time... I jumped on just as the doors were closing!",
        "narrator_thai": "ผู้หญิงหมายความว่าอย่างไร?",
        "script_thai": "(Man): คุณขึ้นรถไฟรอบ 8 โมงทันไหม?\n(Woman): เฉียดฉิว! ครั้งนี้ฉันกะเวลาแบบเส้นยาแดงผ่าแปดเลย (Cut it close)... ฉันกระโดดขึ้นรถไฟตอนประตูกำลังปิดพอดี!",
        "choices_eng": [
            "(A) She arrived early for the train.",
            "(B) She missed the train.",
            "(C) She almost missed the train.",
            "(D) She cut herself on the train."
        ],
        "choices_thai": [
            "(เธอมาถึงก่อนเวลารถไฟออกนาน)",
            "(เธอตกรถไฟ)",
            "(เธอเกือบจะตกรถไฟ)",
            "(เธอทำตัวเองโดนบาดบนรถไฟ)"
        ],
        "answer_text": "เฉลย: (C)\nอธิบาย: สำนวน 'cut it close' แปลว่า ทำอะไรแบบเฉียดเส้นตายมากๆ ซึ่งแปลว่าเกือบจะไม่ทัน (Almost missed)"
    },
    {
        "id": 6,
        "narrator": "What does the man imply?",
        "script_eng": "(Woman): Have you ever met Professor Higgins?\n(Man): Hmm... the name rings a bell... but I can't quite place the face.",
        "narrator_thai": "ผู้ชายบอกเป็นนัยว่าอะไร?",
        "script_thai": "(Woman): คุณเคยเจอศาสตราจารย์ฮิกกินส์ไหม?\n(Man): อืม... ชื่อนี้ฟังดูคุ้นหูนะ (Rings a bell)... แต่นึกหน้าไม่ออกเลยแฮะ",
        "choices_eng": [
            "(A) He knows the professor very well.",
            "(B) He hears a bell ringing.",
            "(C) The name sounds familiar.",
            "(D) He has never heard the name."
        ],
        "choices_thai": [
            "(เขารู้จักศาสตราจารย์ดีมาก)",
            "(เขาได้ยินเสียงกระดิ่งดัง)",
            "(ชื่อนั้นฟังดูคุ้นๆ)",
            "(เขาไม่เคยได้ยินชื่อนี้มาก่อน)"
        ],
        "answer_text": "เฉลย: (C)\nอธิบาย: สำนวน 'rings a bell' หมายถึง ฟังดูคุ้นๆ เหมือนเคยได้ยินมาก่อน (Familiar)"
    },
    {
        "id": 7,
        "narrator": "What implies about the woman's feeling?",
        "script_eng": "(Man): Since it's raining, maybe we should go to the mall instead?\n(Woman): Ugh... Going to a crowded mall on a Saturday is... the last thing I want to do.",
        "narrator_thai": "บทสนทนาบอกอะไรเกี่ยวกับความรู้สึกของผู้หญิง?",
        "script_thai": "(Man): ไหนๆ ฝนก็ตกแล้ว เราไปเดินห้างกันแทนไหม?\n(Woman): เฮ้อ... การไปห้างที่คนแน่นเอียดในวันเสาร์เนี่ย... เป็นสิ่งสุดท้ายที่ฉันอยากจะทำเลยนะ (ไม่อยากไปสุดๆ)",
        "choices_eng": [
            "(A) She really wants to go to the mall.",
            "(B) She thinks the mall is closed.",
            "(C) She has no desire to go to the mall.",
            "(D) She is last in line at the mall."
        ],
        "choices_thai": [
            "(เธออยากไปห้างมากๆ)",
            "(เธอคิดว่าห้างปิด)",
            "(เธอไม่มีความต้องการที่จะไปห้างเลย)",
            "(เธอต่อแถวเป็นคนสุดท้ายที่ห้าง)"
        ],
        "answer_text": "เฉลย: (C)\nอธิบาย: สำนวน 'the last thing I want to do' (สิ่งสุดท้ายที่จะทำ) แปลว่า ไม่อยากทำสิ่งนั้นเลย (No desire)"
    },
    {
        "id": 8,
        "narrator": "What does the man mean?",
        "script_eng": "(Woman): Does Sarah know about the surprise party yet?\n(Man): Oh no... I think I might have... let the cat out of the bag by mistake!",
        "narrator_thai": "ผู้ชายหมายความว่าอย่างไร?",
        "script_thai": "(Woman): ซาร่ารู้เรื่องปาร์ตี้เซอร์ไพรส์หรือยัง?\n(Man): โอ๊ย แย่แล้ว... ผมคิดว่าผมเผลอ... หลุดปากบอกความลับไปแล้วแน่ๆ (Let the cat out of the bag)!",
        "choices_eng": [
            "(A) He bought Sarah a cat.",
            "(B) He accidentally revealed the secret.",
            "(C) He let a cat escape from a bag.",
            "(D) Sarah doesn't like surprises."
        ],
        "choices_thai": [
            "(เขาซื้อแมวให้ซาร่า)",
            "(เขาเผลอเปิดเผยความลับ)",
            "(เขาปล่อยแมวหนีออกจากถุง)",
            "(ซาร่าไม่ชอบเซอร์ไพรส์)"
        ],
        "answer_text": "เฉลย: (B)\nอธิบาย: สำนวน 'let the cat out of the bag' แปลว่า เผลอเปิดเผยความลับ (Revealed the secret)"
    },
    {
        "id": 9,
        "narrator": "What does the woman imply?",
        "script_eng": "(Man): Do you prefer Italian or Mexican food for dinner?\n(Woman): Honestly... it makes no difference to me! I'm starving either way!",
        "narrator_thai": "ผู้หญิงบอกเป็นนัยว่าอะไร?",
        "script_thai": "(Man): มื้อเย็นคุณชอบอาหารอิตาเลียนหรือเม็กซิกันมากกว่ากัน?\n(Woman): เอาจริงๆ นะ... ฉันกินอะไรก็ได้ทั้งนั้นแหละ! (Makes no difference) แบบไหนฉันก็หิวจะแย่อยู่แล้ว!",
        "choices_eng": [
            "(A) She prefers Italian food.",
            "(B) She prefers Mexican food.",
            "(C) She is not hungry.",
            "(D) She has no preference."
        ],
        "choices_thai": [
            "(เธอชอบอาหารอิตาเลียนมากกว่า)",
            "(เธอชอบอาหารเม็กซิกันมากกว่า)",
            "(เธอไม่หิว)",
            "(เธอไม่มีความชอบเป็นพิเศษ/อะไรก็ได้)"
        ],
        "answer_text": "เฉลย: (D)\nอธิบาย: วลี 'it makes no difference to me' แปลว่า สำหรับฉันแล้วมันไม่ต่างกัน หรือเลือกอะไรก็ได้ (No preference)"
    },
    {
        "id": 10,
        "narrator": "What happened to John?",
        "script_eng": "(Woman): I thought John was going to go skydiving with us?\n(Man): He was... until he got cold feet at the last minute!",
        "narrator_thai": "เกิดอะไรขึ้นกับจอห์น?",
        "script_thai": "(Woman): ฉันนึกว่าจอห์นจะไปกระโดดร่มกับเราซะอีก?\n(Man): เขาก็จะไปนั่นแหละ... จนกระทั่งเขาปอดแหก (Got cold feet) ในนาทีสุดท้ายนั่นแหละ!",
        "choices_eng": [
            "(A) His feet were very cold.",
            "(B) He became too afraid to do it.",
            "(C) He went skydiving happily.",
            "(D) He forgot his shoes."
        ],
        "choices_thai": [
            "(เท้าของเขาเย็นเฉียบ)",
            "(เขากลัวจนไม่กล้าทำ)",
            "(เขาไปกระโดดร่มอย่างมีความสุข)",
            "(เขาลืมรองเท้า)"
        ],
        "answer_text": "เฉลย: (B)\nอธิบาย: สำนวน 'get cold feet' แปลว่า เกิดอาการกลัวกะทันหันจนไม่กล้าทำสิ่งที่ตั้งใจไว้ (Too afraid)"
    }
]

# %%
Set 13
